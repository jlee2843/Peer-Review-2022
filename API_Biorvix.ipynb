# %% [markdown]
# <a href="https://colab.research.google.com/github/jlee2843/Peer-Review-22-23/blob/Albert-2022/API_Biorvix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("version:", sys.version)
# Out:
# version: 3.8.15 (default, Oct 12 2022, 19:14:39)
# [GCC 7.5.0]

# %%
import pandas as pd
import numpy as np
import requests
import json
import urllib, urllib.request
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# **Biorxiv API** information is found [here](https://api.biorxiv.org/details/medrxiv/help).<br>
# **Final edit:** December 02, 2022.<br>
# **NB:** Using Jenny's notebook  as a template

# %%
from typing import Union

# common helper function
def get_total (url) -> int:
    json_info = get_json_data(url)
    return json_info["messages"][0]["total"]

def get_json_data (url):
    request_API = requests.get(url)
    return json.loads(request_API.text)

def get_data(file, url, loop_range):
    print(f"values: {list(loop_range)}")
    results = []
    with ThreadPoolExecutor(3) as exe:
        if file is not None:
            args = (((get_json_data(f'{url}/{cursor}'), file) for cursor in loop_range))
            print(args)
            exe.map (lambda p: json.dump(*p), args)

            file.close()
        else:
            results = exe.map(get_json_data, ((f'{url}/{cursor}') for cursor in loop_range))
    
    return results

freq_count = lambda x,y: x[y].value_counts()

flatten = lambda y: sorted([sublist for inner in y for sublist in inner],
                           key=lambda x:x[0])

# %%
# prepublish helper function
def process_prepublish_data(json_info, cursor):
    journal_list = []
    for entry, journal in enumerate(json_info["collection"]):
        journal_list.append([entry + cursor, journal["doi"], journal["title"], journal["authors"],
                             journal["author_corresponding"],
                             journal["author_corresponding_institution"],
                             journal["date"], journal["version"], journal["type"],
                             journal["category"], journal["jatsxml"], journal["published"]])

    return journal_list

def create_prepublish_df(results, loop_list):
    args = zip(results, loop_list)
    #print(f'results: {len(results)} loop_list: {len(list(loop_list))}')
    result_list = []
    with ThreadPoolExecutor(3) as exe:
        result_list = exe.map(lambda p: process_prepublish_data(*p), args)
    
    data = np.array(flatten(result_list))
    df = pd.DataFrame(data=data[:, 1:],
                      index=data[:, 0],
                      columns=["DOI", "Title", "Authors", "Corresponding_Authors",
                               "Institution",
                               "Date", "Version", "Type", "Category", "Xml", "Published"])
    df['Num_of_Authors'] = df.Authors.apply(lambda x: len(x.split(';')))
    df.DOI = df.DOI.astype('str')
    df.Title = df.Title.astype('str')
    df.Authors = df.Authors.astype('str')
    df.Corresponding_Authors = df.Corresponding_Authors.astype('str')
    df.Institution = df.Institution.astype('category')
    df.Date = pd.to_datetime(df.Date, format='%Y-%m-%d')
    df.Type = df.Type.astype('category')
    df.Xml = df.Xml.astype('str')

    return df

#variables
base_url: str = 'https://api.biorxiv.org'
query_type: str = '/details'
server: str = '/biorxiv'
start_interval: str = '/2020-03-01'
end_interval: str = '/2020-03-31'

#finding the number of records for a given time period
#tmp = f"{base_url}/{start_interval}/{end_interval}"
#tmp = 'https://api.biorxiv.org/details/biorxiv/2020-08-21/2020-08-28'
print(f'{base_url}{query_type}{server}{start_interval}{end_interval}')
results = get_data(None, 
         f'{base_url}{query_type}{server}{start_interval}{end_interval}', 
         range(0, get_total(f'{base_url}{query_type}{server}{start_interval}{end_interval}'), 100))

journal_df = create_prepublish_df([r for r in results], 
                                  range(0, get_total(f'{base_url}{query_type}{server}{start_interval}{end_interval}'), 100))

display(journal_df)
# Out:
# https://api.biorxiv.org/details/biorxiv/2020-03-01/2020-03-31
# values: [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200]
#                             DOI  \
# 0                10.1101/099697
# 1                10.1101/106542
# 2                10.1101/121020
# 3                10.1101/124305
# 4                10.1101/124305
# ...                         ...
# 4199  10.1101/2020.03.31.018358
# 4200  10.1101/2020.03.31.018366
# 4201  10.1101/2020.03.31.007492
# 4202  10.1101/2020.03.30.017046
# 4203  10.1101/2020.03.31.014035
#
#                                                   Title  \
# 0     Glucocorticoids and cortical decoding in the p...
# 1     Global cropland connectivity: A risk factor fo...
# 2     A Gaussian process model of human electrocorti...
# 3     A pleiotropic chemoreceptor facilitates the co...
# 4     Chemoreceptor pleiotropy facilitates the funct...
# ...                                                 ...
# 4199  Echocardiography-guided percutaneous left vent...
# 4200  Laser capture microdissection in combination w...
# 4201  Specialisation and plasticity in a primitively...
# 4202  The effects of transcranial direct current sti...
# 4203  Development of an in vitro senescent hepatic c...
#
#                                                 Authors Corresponding_Authors  \
# 0     Schwab, S.; Federspiel, A.; Morishima, Y.; Nak...         Simon  Schwab
# 1     Xing, Y.; Hernandez Nopsa, J.; Andersen, K. F....        Karen  Garrett
# 2     Owen, L. L. W.; Muntianu, T. A.; Heusser, A. C...     Jeremy R. Manning
# 3     Zelle, K.; Vernier, C.; Liang, X.; Halloran, S...    Yehuda  Ben-Shahar
# 4     Zelle, K.; Vernier, C.; Leitner, N.; Liang, X....    Yehuda  Ben-Shahar
# ...                                                 ...                   ...
# 4199  Nong, Y.; Guo, Y.; Tomlin, A.; Zhu, X.; Wysocz...          Yibing  Nong
# 4200  Roudnicky, P.; Potesil, D.; Zdrahal, Z.; Gelna...      Pavel  Roudnický
# 4201  Patalano, S.; Alsina, A.; Gregorio-Rodriguez, ...      Steffen  Rulands
# 4202          Pellegrini, M.; Zoghi, M.; Jaberzadeh, S.   Michael  Pellegrini
# 4203  Singh, B. K.; Tripathi, M.; Yen, P. M.; Sandir...   Brijesh Kumar Singh
#
#                                             Institution       Date Version  \
# 0                 University of Warwick, United Kingdom 2020-03-04       6
# 1                                 University of Florida 2020-03-10       2
# 2                                     Dartmouth College 2020-03-14       3
# 3                    Washington University in St. Louis 2020-03-09       5
# 4                    Washington University in St. Louis 2020-03-21       6
# ...                                                 ...        ...     ...
# 4199        University of Louisville School of Medicine 2020-03-31       1
# 4200       Masarykova univerzita Prirodovedecka Fakulta 2020-03-31       1
# 4201  Max Planck Institute for the Physics of Comple... 2020-03-31       1
# 4202                                  Monash University 2020-03-31       1
# 4203                            Duke-NUS Medical School 2020-03-31       1
#
#              Type      Category  \
# 0     new results  neuroscience
# 1     new results       ecology
# 2     new results  neuroscience
# 3     new results      genetics
# 4     new results      genetics
# ...           ...           ...
# 4199  new results    physiology
# 4200  new results  biochemistry
# 4201  new results    biophysics
# 4202  new results  neuroscience
# 4203  new results  cell biology
#
#                                                     Xml  \
# 0     https://www.biorxiv.org/content/early/2020/03/...
# 1     https://www.biorxiv.org/content/early/2020/03/...
# 2     https://www.biorxiv.org/content/early/2020/03/...
# 3     https://www.biorxiv.org/content/early/2020/03/...
# 4     https://www.biorxiv.org/content/early/2020/03/...
# ...                                                 ...
# 4199  https://www.biorxiv.org/content/early/2020/03/...
# 4200  https://www.biorxiv.org/content/early/2020/03/...
# 4201  https://www.biorxiv.org/content/early/2020/03/...
# 4202  https://www.biorxiv.org/content/early/2020/03/...
# 4203  https://www.biorxiv.org/content/early/2020/03/...
#
#                               Published  Num_of_Authors
# 0     10.1016/j.pscychresns.2020.111066               9
# 1                10.1093/biosci/biaa067              18
# 2                10.1093/cercor/bhaa115               6
# 3                                    NA               6
# 4                                    NA               7
# ...                                 ...             ...
# 4199         10.1007/s11010-021-04077-6               7
# 4200       10.1371/journal.pone.0231681               5
# 4201                                 NA              11
# 4202       10.1016/j.neures.2020.06.002               3
# 4203                                 NA               6
#
# [4204 rows x 12 columns]

# %%
#summary of table
journal_df.describe(include='all')
# Out:
# <ipython-input-9-76d3cc217c13>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   journal_df.describe(include='all')
#                               DOI  \
# count                        4204
# unique                       3853
# top     10.1101/2020.02.28.970814
# freq                            6
# first                         NaN
# last                          NaN
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#                                                     Title  \
# count                                                4204
# unique                                               3903
# top     Frequency dependent sexual selection, mating t...
# freq                                                    4
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        Authors Corresponding_Authors           Institution  \
# count                     4204                  4204                  4204
# unique                    3897                  3627                  2412
# top     Rogers, S.; Lew, V. L.              Rui  Guo  University of Oxford
# freq                         7                     8                    35
# first                      NaN                   NaN                   NaN
# last                       NaN                   NaN                   NaN
# mean                       NaN                   NaN                   NaN
# std                        NaN                   NaN                   NaN
# min                        NaN                   NaN                   NaN
# 25%                        NaN                   NaN                   NaN
# 50%                        NaN                   NaN                   NaN
# 75%                        NaN                   NaN                   NaN
# max                        NaN                   NaN                   NaN
#
#                        Date Version         Type      Category  \
# count                  4204    4204         4204          4204
# unique                   31      11            4            27
# top     2020-03-05 00:00:00       1  new results  neuroscience
# freq                    290    3038         4128           743
# first   2020-03-01 00:00:00     NaN          NaN           NaN
# last    2020-03-31 00:00:00     NaN          NaN           NaN
# mean                    NaN     NaN          NaN           NaN
# std                     NaN     NaN          NaN           NaN
# min                     NaN     NaN          NaN           NaN
# 25%                     NaN     NaN          NaN           NaN
# 50%                     NaN     NaN          NaN           NaN
# 75%                     NaN     NaN          NaN           NaN
# max                     NaN     NaN          NaN           NaN
#
#                                                       Xml Published  \
# count                                                4204      4204
# unique                                               4167      2665
# top     https://www.biorxiv.org/content/early/2020/03/...        NA
# freq                                                    3      1305
# first                                                 NaN       NaN
# last                                                  NaN       NaN
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#         Num_of_Authors
# count      4204.000000
# unique             NaN
# top                NaN
# freq               NaN
# first              NaN
# last               NaN
# mean          7.529020
# std           5.882493
# min           1.000000
# 25%           4.000000
# 50%           6.000000
# 75%           9.000000
# max          53.000000

# %%
#freq count of Num_of_Authors
freq_count(journal_df,'Num_of_Authors')
# Out:
# 3     489
# 4     473
# 5     453
# 6     419
# 2     364
# 7     353
# 8     292
# 9     237
# 10    192
# 11    153
# 12    122
# 1      99
# 13     78
# 14     70
# 15     68
# 16     49
# 17     48
# 18     39
# 19     33
# 21     24
# 20     22
# 24     16
# 25     15
# 22     13
# 27     10
# 26      9
# 31      8
# 29      7
# 23      7
# 34      5
# 47      5
# 35      4
# 45      4
# 32      3
# 30      3
# 28      2
# 46      2
# 33      2
# 44      2
# 43      2
# 39      1
# 40      1
# 41      1
# 36      1
# 37      1
# 53      1
# 38      1
# 49      1
# Name: Num_of_Authors, dtype: int64

# %%
#freq count of Corresponding_Authors
freq_count(journal_df, 'Corresponding_Authors')
# Out:
# Rui  Guo               8
# Virgilio Leon Lew      7
# Zhongyang  Tan         6
# Pierre  Morisse        5
# Silvia  Argimon        5
#                       ..
# Valentyn  Oksenych     1
# Shinji  Fukuda         1
# Adam P Arkin           1
# Tomasz W Turowski      1
# Brijesh Kumar Singh    1
# Name: Corresponding_Authors, Length: 3627, dtype: int64

# %%
#freq count of Instituion
freq_count(journal_df, 'Institution')
# Out:
# University of Oxford                                                                           35
# Stanford University                                                                            29
# University of Cambridge                                                                        28
# University of Michigan                                                                         22
# University of Washington                                                                       21
#                                                                                                ..
# Inria                                                                                           1
# Indraprastha Institute of Information Technology                                                1
# Indiana University Purdue University at Indianapolis, Indiana University School of Medicine     1
# Indian Institute of Technology, Kharagpur-721302, India                                         1
# École polytechnique fédérale de Lausanne                                                        1
# Name: Institution, Length: 2412, dtype: int64

# %%
#freq count of Date
freq_count(journal_df, 'Date')
# Out:
# 2020-03-05    290
# 2020-03-25    282
# 2020-03-18    258
# 2020-03-20    236
# 2020-03-12    203
# 2020-03-31    193
# 2020-03-29    193
# 2020-03-11    190
# 2020-03-06    175
# 2020-03-03    155
# 2020-03-26    152
# 2020-03-02    143
# 2020-03-23    143
# 2020-03-09    142
# 2020-03-04    122
# 2020-03-13    119
# 2020-03-19    119
# 2020-03-08    112
# 2020-03-30    111
# 2020-03-10    100
# 2020-03-27     99
# 2020-03-15     98
# 2020-03-24     97
# 2020-03-14     96
# 2020-03-07     88
# 2020-03-16     67
# 2020-03-17     64
# 2020-03-21     58
# 2020-03-28     49
# 2020-03-22     35
# 2020-03-01     15
# Name: Date, dtype: int64

# %%
#freq count of number of version
freq_count(journal_df, 'Version')
# Out:
# 1     3038
# 2      833
# 3      236
# 4       52
# 5       24
# 6       10
# 7        6
# 8        2
# 13       1
# 19       1
# 9        1
# Name: Version, dtype: int64

# %%
#freq count of Type
freq_count(journal_df, 'Type')
# Out:
# new results              4128
# confirmatory results       45
# contradictory results      24
# withdrawn                   7
# Name: Type, dtype: int64

# %%
#freq count Category
freq_count(journal_df, 'Category')
# Out:
# neuroscience                              743
# microbiology                              437
# bioinformatics                            390
# cell biology                              233
# genomics                                  225
# evolutionary biology                      212
# ecology                                   205
# biochemistry                              196
# biophysics                                176
# molecular biology                         171
# cancer biology                            170
# immunology                                163
# genetics                                  150
# plant biology                             142
# developmental biology                     119
# bioengineering                            103
# systems biology                            78
# animal behavior and cognition              77
# physiology                                 66
# pharmacology and toxicology                39
# synthetic biology                          35
# pathology                                  26
# scientific communication and education     24
# zoology                                    17
# epidemiology                                3
# paleontology                                3
# clinical trials                             1
# Name: Category, dtype: int64

# %%
assert num_entries == len(journal_df)
"Total number of papers submitted and the length of the dataframe does match."
# Out:
# 'Total number of papers submitted and the length of the dataframe does match.'

# %% [markdown]
# The above code runs through all papers that are submitted within selected time frame. Error discussed during the previous meeting has been fixed.

# %% [markdown]
# ----

# %% [markdown]
# Query of Published Articles for a given timefame

# %%
# helper functions for published articles
def process_published_data(json_info, cursor) -> list:
    journal_list = []

    for entry, journal in enumerate(json_info["collection"]):
        journal_list.append([entry + cursor, journal["preprint_doi"], 
                             journal["published_doi"],
                             journal["preprint_title"], journal["preprint_authors"],
                             journal["preprint_author_corresponding"],
                             journal["preprint_author_corresponding_institution"],
                             journal["preprint_category"], journal["published_journal"],
                             journal["preprint_date"], journal["published_date"]])

    print(f"journal_list: {len(journal_list)}\n{journal_list}")
    return journal_list

def create_published_df(results, loop_list):
    args = zip(results, loop_list)
    #print(f'results: {len(results)} loop_list: {len(list(loop_list))}')
    result_list = []
    with ThreadPoolExecutor(3) as exe:
        result_list = exe.map(lambda p: process_published_data(*p), args)

    data = np.array(flatten(result_list))
    df = pd.DataFrame(data=data[:, 1:],
                      index=data[:, 0],
                      columns=["pre_DOI", "pub_DOI",
                               "Title", "Authors", "Corresponding_Authors",
                               "Institution",
                               "Category", "Journal", "Preprint_Date", "Published_Date"])
    df['Num_of_Authors'] = df.Authors.apply(lambda x: len(x.split(';')))
    df.pre_DOI = df.pre_DOI.astype('str')
    df.pub_DOI = df.pub_DOI.astype('str')
    df.Title = df.Title.astype('str')
    df.Authors = df.Authors.astype('str')
    df.Corresponding_Authors = df.Corresponding_Authors.astype('str')
    df.Institution = df.Institution.astype('category')
    df.Category = df.Category.astype('category')
    df.Journal = df.Journal.astype('category')
    df.Preprint_Date = pd.to_datetime(df.Preprint_Date, format='%Y-%m-%d')
    df.Published_Date = pd.to_datetime(df.Published_Date, format='%Y-%m-%d')

    return df

#variables
#https://api.biorxiv.org/pubs/biorvix/2018-08-21/2018-08-28
query_type: str = '/pubs'
start_interval: str = '/2020-03-01'
end_interval: str = '/2020-03-31'

#finding the number of records for a given time period

print(f'{base_url}{query_type}{server}{start_interval}{end_interval}')
results = get_data(None, 
                   f'{base_url}{query_type}{server}{start_interval}{end_interval}', 
                   range(0, get_total(f'{base_url}{query_type}{server}{start_interval}{end_interval}'), 100))

pubs_df = create_published_df([r for r in results], 
                              range(0, get_total(f'{base_url}{query_type}{server}{start_interval}{end_interval}'), 100))

display(pubs_df)
# Out:
# https://api.biorxiv.org/pubs/biorxiv/2020-03-01/2020-03-31
# values: [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500]
# journal_list: 100
# [[0, '10.1101/759530', '10.1101/gad.332643.119', 'Senolytic treatment targets aberrant p21-expression to restore liver regeneration in adult mice', 'Ritschka, B.; Knauer-Meyer, T.; Mas, A.; Plassat, J.-L.; Sampaio Goncalves, D.; Jacobs, H.; Pedone, E.; Di Vicino, U.; Cosma, M. P.; Keyes, W. M.', 'William M. Keyes', 'IGBMC', 'cell biology', 'Genes & Development', '2019-09-05', '2020-03-05'], [1, '10.1101/843441', '10.3389/fnins.2020.00182', 'Functional Connectivity Evoked by Orofacial Tactile Perception of Velocity', 'Wang, Y.; Sibaii, F.; Custead, R.; Oh, H.; Barlow, S. M.', 'Yingying  Wang', 'University of Nebraska-Lincoln', 'neuroscience', 'Frontiers in Neuroscience', '2019-11-16', '2020-03-06'], [2, '10.1101/681353', '10.1038/s41593-020-0603-0', 'Connecting gene regulatory relationships to neurobiological mechanisms of brain disorders', 'Sey, N. Y. A.; Fauni, H.; Ma, W.; Won, H.', 'Hyejung  Won', 'University of North Carolina- Chapel Hill', 'neuroscience', 'Nature Neuroscience', '2019-06-24', '2020-03-09'], [3, '10.1101/796433', '10.1016/j.neuroimage.2020.116698', 'Intersubject consistent dynamic connectivity during natural vision revealed by functional MRI', 'Di, X.; Biswal, B. B.', 'Bharat B Biswal', 'New Jersey Institute of Technology', 'neuroscience', 'NeuroImage', '2019-10-07', '2020-03-01'], [4, '10.1101/838573', '10.1111/1462-2920.14966', 'Genome Repository of Oiled Systems (GROS): an interactive and searchable database that expands the catalogued diversity of crude oil-associated microbes', 'Karthikeyan, S.; Rodriguez-R, L. M.; Heritier-Robbins, P.; Hatt, J.; Huettel, M.; Kostka, J. E.; Konstantinidis, K. T.', 'Konstantinos T  Konstantinidis', 'Georgia Institute of Technology', 'genomics', 'Environmental Microbiology', '2019-11-12', '2020-03-02'], [5, '10.1101/793471', '10.1111/1462-2920.14968', 'The biogeography and biodiversity of endophytes--how far have we come and where do we go from here?', 'Harrison, J. G.; Griffin, E. A.', 'Joshua G Harrison', 'University of Wyoming', 'ecology', 'Environmental Microbiology', '2019-10-09', '2020-03-02'], [6, '10.1101/776609', '10.1111/eva.12939', 'Evaluating the Probability of CRISPR-based Gene Drive Contaminating Another Species', 'Courtier-Orgogozo, V.; Danchin, A.; Gouyon, P.-H.; Boete, C.', 'Virginie  Courtier-Orgogozo', 'Institut Jacques Monod / CNRS / Universite de Paris', 'genetics', 'Evolutionary Applications', '2019-09-19', '2020-03-02'], [7, '10.1101/2020.01.14.906859', '10.1002/ecy.3029', 'Species-specific, age-varying plant traits affect herbivore growth and survival', 'Yang, L. H.; Cenzer, M. L.; Morgan, L. J.; Hall, G. W.', 'Louie H. Yang', 'University of California, Davis', 'ecology', 'Ecology', '2020-01-14', '2020-03-02'], [8, '10.1101/697409', '10.1038/s41598-020-60873-y', '64-Channel Carbon Fiber Electrode Arrays for Chronic Electrophysiology', 'Guitchounts, G.; Cox, D. D.', 'Grigori  Guitchounts', 'Harvard University', 'neuroscience', 'Scientific Reports', '2019-07-09', '2020-03-02'], [9, '10.1101/2020.01.13.903906', '10.1038/s41598-020-60733-9', 'Deep Evolutionary History of the Phox and Bem1 (PB1) Domain Across Eukaryotes', 'Mutte, S.; Weijers, D.', 'Dolf  Weijers', 'Wageningen University', 'evolutionary biology', 'Scientific Reports', '2020-01-14', '2020-03-02'], [10, '10.1101/2020.01.06.894147', '10.1039/D0LC00009D', 'Low-cost microphysiological systems: Feasibility study of a tape-based barrier-on-chip system for small intestine modeling', 'Winkler, T. E.; Feil, M.; Stronkman, E. F.; Matthiesen, I.; Herland, A.', 'Thomas E Winkler', 'Division of Micro- and Nanosystems, KTH Royal Institute of Technology, Stockholm, Sweden', 'bioengineering', 'Lab on a Chip', '2020-01-06', '2020-03-02'], [11, '10.1101/842831', '10.1016/j.cma.2020.112935', 'Three-dimensional traction microscopy accounting for cell-induced matrix degradation', 'Song, D.; Seidl, D. T.; Oberai, A. A.', 'Dawei  Song', 'University of Southern California', 'biophysics', 'Computer Methods in App ...
# journal_list: 100
# [[100, '10.1101/2019.12.18.881003', '10.1371/journal.pone.0227316', 'Phenylephrine induces relaxation of longitudinal strips from small arteries of goat legs', 'Marconi, K. P.; Bharathi, B.; Venis, A. M.; Raj, R.; Amirtham, S. M.; Subramani, S.', 'Sathya  Subramani', 'Christian medical college', 'physiology', 'PLOS ONE', '2019-12-18', '2020-03-03'], [101, '10.1101/425306', '10.1371/journal.pone.0230000', 'Changes in pregnancy-related serum biomarkers early in gestation are associated with later development of preeclampsia', 'Hao, S.; You, J.; Chen, L.; Zhao, H.; Huang, Y.; Zheng, L.; Tian, L.; Maric, I.; Liu, X.; Li, T.; Bianco, Y. K.; Winn, V. D.; AGHAEEPOUR, N.; Gaudilliere, B.; Angst, M. S.; Zhou, X.; Li, Y.-M.; Mo, L.; Wong, R. J.; Shaw, G. M.; Stevenson, D.; Cohen, H. J.; MCELHINNEY, D. B.; Sylvester, K. G.; Ling, X. B.', 'Xuefeng B Ling', 'Stanford University', 'molecular biology', 'PLOS ONE', '2018-09-26', '2020-03-03'], [102, '10.1101/741496', '10.1371/journal.pntd.0007719', 'Responses of the putative trachoma vector, Musca sorbens, to volatile semiochemicals from human faeces', "Robinson, A.; Bristow, J.; Holl, M. V.; Makalo, P.; Alemayehu, W.; Bailey, R. L.; McLeod, D.; Birkett, M. A.; Caulfield, J. C.; Sarah, V.; Pickett, J. A.; Dewhirst, S.; Chen-Hussey, V.; Woodcock, C.; D'Alessandro, U.; Burton, M. J.; Last, A.; Lindsay, S. W.; Logan, J. G.", 'Ailie  Robinson', 'London School of Hygiene and Tropical Medicine', 'ecology', 'PLOS Neglected Tropical Diseases', '2019-08-20', '2020-03-03'], [103, '10.1101/775783', '10.1371/journal.pcbi.1007406', 'Fly-QMA: Automated analysis of mosaic imaginal discs in Drosophila', 'Bernasek, S. M.; Pelaez, N.; Carthew, R.; Bagheri, N.; Amaral, L.', 'Sebastian  Michal  Bernasek', 'Northwestern University', 'systems biology', 'PLOS Computational Biology', '2019-09-19', '2020-03-03'], [104, '10.1101/849406', '10.1111/jeb.13610', 'Climate associated genetic variation in Fagus sylvatica and potential responses to climate change in the French Alps.', 'Capblancq, T.; Morin, X.; Gueguen, M.; Renaud, J.; Lobreaux, S.; Bazin, E.', 'Thibaut  Capblancq', 'Univ. Grenoble Alpes, CNRS, LECA UMR 5553, Grenoble, France', 'evolutionary biology', 'Journal of Evolutionary Biology', '2019-11-21', '2020-03-03'], [105, '10.1101/746800', '10.1021/acs.jctc.9b00929', 'Interpretation of Phase Boundary Fluctuation Spectra in Biological Membranes with Nanoscale Organization', 'Iyer, S. S.; Negi, A.; Srivastava, A.', 'Anand  Srivastava', 'Indian Institute of Science, Bangalore', 'biophysics', 'Journal of Chemical Theory and Computation', '2019-08-27', '2020-03-03'], [106, '10.1101/842229', '10.1002/humu.24008', 'Type II Alexander disease caused by splicing errors and aberrant overexpression of an uncharacterized GFAP isoform.', 'Helman, G.; Takanohashi, A.; Hagemann, T. L.; Perng, M. D.; Walkiewicz, M.; Woidill, S.; Sase, S.; Cross, Z.; Du, Y.; Zhao, L.; Waldman, A.; Haake, B. C.; Fatemi, A.; Brenner, M.; Sherbini, O.; Messing, A.; Vanderver, A.; Simons, C.', 'Cas  Simons', "Murdoch Children's Research Institute", 'genetics', 'Human Mutation', '2019-11-21', '2020-03-03'], [107, '10.1101/712331', '10.1101/gr.255463.119', 'Genome-wide, integrative analysis implicates circular RNA dysregulation in autism and the corresponding circular RNA-microRNA-mRNA regulatory axes', 'Chen, Y.-J.; Chen, C.-Y.; Mai, T.-L.; Chuang, C.-F.; Gupta, S. K.; Yen, L.; Wang, Y.-D.; Chuang, T.-J.', 'Trees-Juen  Chuang', 'Genomics Research Center, Academia Sinica, Taipei, Taiwan.', 'bioinformatics', 'Genome Research', '2019-07-24', '2020-03-03'], [108, '10.1101/855544', '10.1073/pnas.1920747117', 'RNA extension drives a stepwise displacement of an initiation-factor structural module in initial transcription', 'Li, L.; Molodtsov, V.; Lin, W.; Ebright, R. H.; Zhang, Y.', 'Richard H. Ebright', 'Waksman Institute, Rutgers University', 'biochemistry', 'Proceedings of the National Academy of Sciences', '2019-11-26', '2020-03-03'], [109, '10.1101/756 ...
# journal_list: 100
# [[200, '10.1101/698860', '10.1093/molbev/msaa075', 'Model fit does not predict accuracy in single-gene protein phylogenetics', 'Spielman, S.', 'Stephanie  Spielman', 'Rowan University', 'evolutionary biology', 'Molecular Biology and Evolution', '2019-07-11', '2020-03-18'], [201, '10.1101/864967', '10.1021/acsami.9b22116', 'Cultivation of Exoelectrogenic Bacteria in Conductive DNA Nanocomposite Hydrogels Yields a Programmable Biohybrid Materials System', 'Hu, Y.; Rehnlund, D.; Klein, E.; Gescher, J.; Niemeyer, C. M.', 'Christof M Niemeyer', 'Karlsruhe Institute of Technology', 'biochemistry', 'ACS Applied Materials & Interfaces', '2019-12-05', '2020-03-19'], [202, '10.1101/628321', '10.1083/jcb.201905028', 'Reactive oxygen species (ROS) production triggers unconventional secretion of antioxidant enzymes', 'Cruz-Garcia, D.; Brouwers, N.; Malhotra, V.; Curwin, A. J.', 'Amy J Curwin', 'Centre for Genomic Regulation', 'cell biology', 'Journal of Cell Biology', '2019-05-05', '2020-03-19'], [203, '10.1101/843649', '10.7554/eLife.53807', 'Microneedle manipulation of the mammalian spindle reveals specialized, short-lived reinforcement near chromosomes', 'Suresh, P.; Long, A. F.; Dumont, S.', 'Sophie  Dumont', 'University of California, San Francisco', 'cell biology', 'eLife', '2019-11-15', '2020-03-19'], [204, '10.1101/459883', '10.1093/texcom/tgaa004', 'Increased Blood Flow and Oxidative Metabolism in the Human Brain by Transcranial Laser Stimulation', 'Dmochowski, G. M.; Dmochowski, J.', 'Jacek  Dmochowski', 'City College of New York', 'neuroscience', 'Cerebral Cortex Communications', '2018-11-02', '2020-03-19'], [205, '10.1101/690586', '10.1002/ajhb.23414', 'A missense variant in CREBRF is associated with taller stature in Samoans', 'Carlson, J. C.; Rosenthal, S. L.; Russell, E. M.; Hawley, N. L.; Sun, G.; Cheng, H.; Naseri, T.; Reupena, M. S.; Tuitele, J.; Deka, R.; McGarvey, S. T.; Weeks, D. E.; Minster, R. L.', 'Jenna C Carlson', 'University of Pittsburgh', 'genetics', 'American Journal of Human Biology', '2019-07-02', '2020-03-19'], [206, '10.1101/511402', '10.1128/AAC.02026-19', 'Reconciling the potentially irreconcilable? Genotypic and phenotypic amoxicillin-clavulanate resistance in  Escherichia coli', 'Davies, T. J.; Stoesser, N.; Sheppard, A. E.; Abuoun, M.; Fowler, P. W.; Swann, J.; Quan, P.; Griffiths, D.; Vaughan, A.; Morgan, M.; Phan, H. T. T.; Jeffery, K. J.; Andersson, M.; Ellington, M.; Ekelund, O.; Mathers, A.; Bonomo, R.; Woodford, N.; Crook, D. W.; Peto, T. E.; Anjum, M.; Walker, A. S.', 'Timothy J Davies', 'University of Oxford', 'microbiology', 'Antimicrobial Agents and Chemotherapy', '2019-01-07', '2020-03-19'], [207, '10.1101/2020.03.09.984856', '10.1128/AAC.00440-20', 'Tilorone: A Broad-Spectrum Antiviral For Emerging Viruses', 'Ekins, S.; Madrid, P.', 'Sean  Ekins', 'Collaborations Pharmaceuticals Inc', 'pharmacology and toxicology', 'Antimicrobial Agents and Chemotherapy', '2020-03-11', '2020-03-19'], [208, '10.1101/679886', '10.1038/s41598-020-61992-2', 'Tumor fitness, immune exhaustion and clinical outcomes: impact of immune checkpoint inhibitors', 'Bubie, A.; Kozlova, E. G.; Akers, N.; Villanueva, A.; Losic, B.', 'Bojan  Losic', 'Department of Genetics and Genomic Sciences, Tisch Cancer Institute, Cancer Immunology, Diabetes', 'cancer biology', 'Scientific Reports', '2019-06-23', '2020-03-19'], [209, '10.1101/847251', '10.1016/j.envpol.2020.114395', 'Exposure during embryonic development to Roundup(R) Power 2.0 affects lateralization, level of activity and growth, but not defensive behaviour of marsh frog tadpoles', 'Bolis, A.; Gazzola, A.; Pellitteri-Rosa, D.; Colombo, A.; Bonfanti, P.; Bellati, A.', 'Adriana  Bellati', 'University of Pavia', 'zoology', 'Environmental Pollution', '2019-11-20', '2020-03-19'], [210, '10.1101/728956', '10.1111/evo.13957', 'Density-dependent effects of mortality on the optimal body size of a habitat shift: Why smaller is better despite increased mortality risk?', 'Chaparro  ...
# journal_list: 100
# [[300, '10.1101/482125', '10.1038/s41419-020-2391-6', 'Helicobacter pylori-induced adrenomedullin modulates IFN-γ-producing T-cell responses and contribute to gastritis', 'Zhuang, Y.; Kong, H.; Zhang, J.-y.; Mao, F.-y.; Teng, Y.-s.; Lv, Y.-p.; Liu, Y.-g.; Chen, W.; Zhang, Y.; Guo, G.', 'Yuan  Zhuang', 'Third Military Medical University', 'immunology', 'Cell Death & Disease', '2018-11-28', '2020-03-17'], [301, '10.1101/2020.01.07.894832', '10.1038/s41380-020-0708-6', 'Inhibitory regulation of calcium transients in prefrontal dendritic spines is compromised by a nonsense Shank3 mutation', 'Ali, F.; Shao, L.-X.; Gerhard, D. M.; Sweasy, K.; Pothula, S.; Pittenger, C.; Duman, R. S.; Kwan, A. C.', 'Alex C Kwan', 'Yale University', 'neuroscience', 'Molecular Psychiatry', '2020-01-08', '2020-03-11'], [302, '10.1101/2020.01.28.923672', '10.1002/cbic.202000056', 'Responsive fluorophore aggregation provides spectral contrast for fluorescence lifetime imaging', 'Schleyer, K. A.; Datko, B. D.; Burnside, B.; Cui, C.; Ma, X.; Grey, J. K.; Cui, L.', 'Lina  Cui', 'University of Florida', 'biochemistry', 'ChemBioChem', '2020-01-29', '2020-03-17'], [303, '10.1101/853606', '10.3389/fpls.2020.00288', 'A versatile high throughput screening platform for plant metabolic engineering highlights the major role of ABI3 in lipid metabolism regulation', 'Pouvreau, B.; Blundell, C.; Vohra, H.; Zwart, A. B.; Arndell, T.; Singh, S.; Vanhercke, T.', 'Benjamin  Pouvreau', 'CSIRO', 'plant biology', 'Frontiers in Plant Science', '2019-11-24', '2020-03-17'], [304, '10.1101/763490', '10.1093/hmg/ddaa046', 'CNS Glycosylphosphatidylinositol Deficiency Results in Delayed White Matter Development, Ataxia, and Premature Death in a Novel Mouse Model', 'Lukacs, M.; Stottmann, R. W.', 'Rolf W Stottmann', "Cincinnati Children's Hospital Medical Center", 'developmental biology', 'Human Molecular Genetics', '2019-09-09', '2020-03-11'], [305, '10.1101/859603', '10.1186/s12859-020-3439-4', 'Variant effect predictions capture some aspects of deep mutational scanning experiments', 'Reeb, J.; Wirth, T.; Rost, B.', 'Jonas  Reeb', 'Technical University Munich', 'bioinformatics', 'BMC Bioinformatics', '2019-11-29', '2020-03-17'], [306, '10.1101/692665', '10.1186/s12859-020-3443-8', 'MethylNet: A Modular Deep Learning Approach to Methylation Prediction', 'Levy, J. J.; Titus, A. J.; Petersen, C. L.; Chen, D.; Salas, L. A.; Christensen, B. C.', 'Joshua J Levy', 'Program in Quantitative Biomedical Sciences, Geisel School of Medicine at Dartmouth, Lebanon, NH 037', 'bioinformatics', 'BMC Bioinformatics', '2019-07-04', '2020-03-17'], [307, '10.1101/585745', '10.1111/1755-0998.13156', 'Error, noise and bias in de novo transcriptome assemblies', 'Freedman, A. H.; Clamp, M.; Sackton, T. B.', 'Adam H Freedman', 'Harvard University', 'bioinformatics', 'Molecular Ecology Resources', '2019-03-22', '2020-03-17'], [308, '10.1101/2020.02.24.961524', '10.1021/acsptsci.0c00022', 'The influence of peptide context on signalling and trafficking of glucagon-like peptide-1 receptor biased agonists', 'Fang, Z.; Chen, S.; Pickford, P.; Broichhagen, J.; Hodson, D.; Correa, I. R.; Kumar, S.; Gorlitz, F.; Dunsby, C.; French, P.; Rutter, G. A.; Tan, T.; Bloom, S. R.; Tomas, A.; Jones, B.', 'Ben  Jones', 'Imperial College London', 'pharmacology and toxicology', 'ACS Pharmacology & Translational Science', '2020-02-25', '2020-03-17'], [309, '10.1101/605402', '10.1136/bmjopen-2019-032866', 'Double burden of malnutrition in children aged 24-59 months by socioeconomic status in five South Asian countries: evidence from Demographic and Health Surveys', 'Hossain, F. B.; Shawon, M. S. R.; Al-Abid, M. S. U.; Sami, S. M.; Adhikary, G.; Bulbul, M. M. I.', 'Fariha Binte  Hossain', 'Independent Researcher', 'epidemiology', 'BMJ Open', '2019-04-12', '2020-03-17'], [310, '10.1101/854711', '10.1186/s40478-020-00909-6', 'Loss of BICD2 in muscle drives motor neuron loss in a developmental form of spinal muscular atrophy', 'Rossor, ...
# [[400, '10.1101/859462', '10.3389/fgene.2020.00210', 'Hardy-Weinberg Equilibrium in the Large Scale Genomic Sequencing Era', 'Abramovs, N.; Brass, A.; Tassabehji, M.', 'May  Tassabehji', 'University of Manchester', 'bioinformatics', 'Frontiers in Genetics', '2019-11-29', '2020-03-13'], [401, '10.1101/465690', '10.1038/s41396-020-0624-4', 'Lipid analysis of CO2-rich subsurface aquifers suggests an autotrophy-based deep biosphere with lysolipids enriched in CPR bacteria', 'Probst, A. J.; Elling, F. J.; Castelle, C. J.; Zhu, Q.; Elvert, M.; Birarda, G.; Holman, H.-Y.; Lane, K. R.; Ladd, B.; Ryan, M. C.; Woyke, T.; Hinrichs, K.-U.; Banfield, J. F.', 'Alexander J Probst', 'Department of Earth and Planetary Science, University of California, Berkeley, CA 94720, USA', 'microbiology', 'The ISME Journal', '2018-11-08', '2020-03-13'], [402, '10.1101/641514', '10.7554/eLife.47946', 'Effect of helical kink in antimicrobial peptides on membrane pore formation', 'Türkova, A.; Kabelka, I.; Kralova, T.; Sukenik, L.; Pokorna, S.; Hof, M.; Vacha, R.', 'Robert  Vécha', 'Masaryk University', 'biophysics', 'eLife', '2019-05-19', '2020-03-13'], [403, '10.1101/672824', '10.1128/MCB.00663-19', 'TWIST1 homo- and heterodimers orchestrate specificity control in embryonic stem cell lineage differentiation and craniofacial development', 'Fan, X.; Waardenberg, A. J.; Demuth, M.; Osteil, P.; Sun, J.; Loebel, D. A. F.; Graham, M.; Tam, P. P. L.; Fossat, N.', 'Xiaochen  Fan', 'CMRI, the University of Sydney', 'developmental biology', 'Molecular and Cellular Biology', '2019-06-16', '2020-03-13'], [404, '10.1101/2020.01.06.896845', '10.1128/MCB.00003-20', 'Identification of a PRC2 accessory subunit required for subtelomeric H3K27 methylation in Neurospora', 'McNaught, K. J.; Wiles, E. T.; Selker, E. U.', 'Eric U  Selker', 'University of Oregon', 'molecular biology', 'Molecular and Cellular Biology', '2020-01-07', '2020-03-13'], [405, '10.1101/782409', '10.1128/JVI.01734-19', 'Coronavirus Interferon Antagonists Differentially Modulate the Host Response during Replication in Macrophages', 'Deng, X.; Volk, A.; Chen, Y.; Kesely, K. R.; Hackbart, M.; Mettelman, R. C.; OBrien, A.; Mesecar, A. D.; Baker, S.', 'Susan C Baker', 'Loyola', 'microbiology', 'Journal of Virology', '2019-09-25', '2020-03-13'], [406, '10.1101/572065', '10.1038/s41380-020-0707-7', 'CRISPR disruption and UK Biobank analysis of a highly conserved polymorphic enhancer suggests its role in anxiety and male alcohol intake.', 'McEwan, A. R.; Hay, E.; Davidson, C.; Turnbull, Y.; Marini, P.; Wilson, D.; McIntosh, A.; Adams, M. J.; Murgatroyd, C.; Barrett, P.; Delibegovic, M.; Clarke, T.-K.; MacKenzie, A.', 'Alasdair  MacKenzie', 'University of Aberdeen', 'genetics', 'Molecular Psychiatry', '2019-03-09', '2020-03-13'], [407, '10.1101/494914', '10.1038/s41467-020-15185-0', 'Nucleosome positioning stability is a significant modulator of germline mutation rate variation across the human genome', 'Li, C.; Luscombe, N. M.', 'Cai  Li', 'Francis Crick Institute', 'genomics', 'Nature Communications', '2018-12-13', '2020-03-13'], [408, '10.1101/822502', '10.3389/fphys.2020.00158', 'A novel MRI-based finite element modeling method for calculation of myocardial ischemia effect in patients with functional mitral regurgitation.', 'Zhang, Y.; Wang, V. Y.; Morgan, A. E.; Kim, J.; Ge, L.; Guccione, J. M.; Weinsaft, J. W.; Ratcliffe, M. B.', 'Mark B Ratcliffe', 'Department of Surgery, University of California, San Francisco; Veterans Affairs Medical Center, San Francisco', 'bioengineering', 'Frontiers in Physiology', '2019-10-29', '2020-03-13'], [409, '10.1101/679597', '10.1038/s41467-020-15166-3', 'Cell-in-the-loop pattern formation with optogenetically emulated cell-to-cell signaling', 'Perkins, M. L.; Benzinger, D.; Arcak, M.; Khammash, M.', 'Melinda Liu  Perkins', 'University of California, Berkeley', 'synthetic biology', 'Nature Communications', '2019-06-22', '2020-03-13'], [410, '10.1101/2019.12.11.872812', '10.1 ...
# journal_list: 100
# [[500, '10.1101/681551', '10.1371/journal.pgen.1008270', 'Drosophila insulin-like peptide 2 mediates dietary regulation of sleep intensity', 'Brown, E.; Shah, K.; Faville, R.; Kottler, B.; Keene, A. C.', 'Alex  C  Keene', 'Florida Atlantic University', 'neuroscience', 'PLOS Genetics', '2019-06-24', '2020-03-11'], [501, '10.1101/740142', '10.1371/journal.pone.0221838', 'Pragmatic selection of larval mosquito diets for insectary rearing of Anopheles gambiae and Aedes aegypti', 'Benedict, M. Q.; Hunt, C. M.; Vella, M. G.; Gonzalez, K. M.; Dotson, E. M.; Collins, C. M.', 'Mark  Quentin  Benedict', 'Centers for Disease Control and Prevention', 'physiology', 'PLOS ONE', '2019-08-19', '2020-03-11'], [502, '10.1101/856229', '10.1371/journal.pone.0226315', 'Plant Bioindicators of Pollution in Sadat City, Western Nile Delta, Egypt', 'Azzazy, M. F.; Azzazy, M. F.', 'Mohamed  F.  Azzazy', 'Environmental studies and research Institute', 'ecology', 'PLOS ONE', '2019-11-26', '2020-03-11'], [503, '10.1101/2019.12.19.882605', '10.1371/journal.pone.0230241', 'A portable, low-cost device for precise control of specimen temperature under stereomicroscopes', 'Testa, N. D.; Kaul, S.; Le, K. N.; Zhan, M.; Lu, H.; Paaby, A. B.', 'Annalise B Paaby', 'School of Biological Sciences, Georgia Institute of Technology, Atlanta, GA 30332, USA', 'developmental biology', 'PLOS ONE', '2019-12-19', '2020-03-11'], [504, '10.1101/706622', '10.1371/journal.pone.0228914', 'Why we publish where we do: Faculty publishing values and their relationship to review, promotion and tenure expectations', 'Niles, M. T.; Schimanski, L. A.; McKiernan, E. C.; Alperin, J. P.', 'Meredith T Niles', 'University of Vermont', 'scientific communication and education', 'PLOS ONE', '2019-07-21', '2020-03-11'], [505, '10.1101/776575', '10.1111/febs.15292', 'Fibroblast-specific genome-scale modelling predicts an imbalance in amino acid metabolism in Refsum disease', 'Wegrzyn, A. B.; Herzog, K.; Gerding, A.; Kwiatkowski, M.; Wolters, J. C.; Dolga, A. M.; van Lint, A. E. M.; Wanders, R. J. A.; Waterham, H. R.; Bakker, B. M.', 'Barbara M. Bakker', 'University Medical Centre Groningen, University of Groningen', 'systems biology', 'The FEBS Journal', '2019-09-19', '2020-03-11'], [506, '10.1101/310433', '10.1038/s41586-020-2105-3', 'U1 snRNP regulates chromatin retention of noncoding RNAs', 'Yin, Y.; Lu, J. Y.; Zhang, X.; Shao, W.; Xu, Y.; Li, P.; Hong, Y.; Zhang, Q. C.; Shen, X.', 'Xiaohua  Shen', 'Tsinghua University', 'molecular biology', 'Nature', '2018-04-29', '2020-03-11'], [507, '10.1101/800508', '10.1038/s41586-020-2088-0', 'Structure of SWI/SNF chromatin remodeller RSC bound to a nucleosome', 'Wagner, F. R.; Dienemann, C.; Wang, H.; Stuetzer, A.; Tegunov, D.; Urlaub, H.; Cramer, P.', 'Patrick  Cramer', 'Max Planck Institute for Biophysical Chemistry', 'molecular biology', 'Nature', '2019-10-14', '2020-03-11'], [508, '10.1101/2020.01.09.900332', '10.1099/mgen.0.000343', 'Bovine viral diarrhoea virus loses quasispecies diversity rapidly in culture', 'Russell, G. C.; Zadoks, R. N.; Willoughby, K.; Bachofen, C.', 'George C Russell', 'Moredun Research Institute', 'evolutionary biology', 'Microbial Genomics', '2020-01-09', '2020-03-11'], [509, '10.1101/803825', '10.1099/ijsem.0.004047', 'Yersinia canariae sp. nov., isolated from a human yersiniosis case', 'Nguyen, S. V.; Greig, D.; Hurley, D.; Cao, Y.; McCabe, E.; Mitchell, M.; Jenkins, C.; Fanning, S.', 'Scott V Nguyen', 'University College Dublin', 'microbiology', 'International Journal of Systematic and Evolutionary Microbiology', '2019-10-18', '2020-03-11'], [510, '10.1101/761593', '10.1016/j.neuron.2020.02.013', 'Constructing and Forgetting Temporal Context in the Human Cerebral Cortex', 'Chien, H.-Y. S.; Honey, C. J.', 'Christopher J. Honey', 'Johns Hopkins University', 'neuroscience', 'Neuron', '2019-09-08', '2020-03-11'], [511, '10.1101/686956', '10.1182/blood.2019002385', 'Coding and regulatory drivers of mantle cell lymphoma identifi ...
#
# journal_list: 100
# [[600, '10.1101/793455', '10.1371/journal.pcbi.1007741', 'ProteoClade: a taxonomic toolkit for multi-species and metaproteomic analysis', 'Mooradian, A. D.; van der Post, S.; Naegle, K. M.; Held, J. M.', 'Jason M Held', 'Washington University in St. Louis', 'bioinformatics', 'PLOS Computational Biology', '2019-10-07', '2020-03-09'], [601, '10.1101/838235', '10.1371/journal.pntd.0007910', 'Dispersal patterns of Trypanosoma cruzi in Arequipa, Peru', 'Berry, A. S. F.; Salazar-Sanchez, R.; Castillo-Neyra, R.; Borrini-Mayori, K.; Arevalo-Nieto, C.; Chipana-Ramos, C.; Vargas-Maquera, M.; Ancca-Juarez, J.; Naquira-Velarde, C.; Levy, M. Z.; Brisson, D.', 'Alexander  S.F.  Berry', "Children's Hospital of Philadelphia", 'evolutionary biology', 'PLOS Neglected Tropical Diseases', '2019-11-11', '2020-03-09'], [602, '10.1101/585265', '10.1371/journal.pgen.1008552', 'Tracking human population structure through time from whole genome sequences', "Wang, K.; Mathieson, I.; O'Connell, J.; Schiffels, S.", 'Stephan  Schiffels', 'Department of Archaeogenetics, Max Planck Institute for the Science of Human History, Jena, Germany', 'evolutionary biology', 'PLOS Genetics', '2019-03-21', '2020-03-09'], [603, '10.1101/765032', '10.1371/journal.pgen.1008646', 'Long transposon-rich centromeres in an oomycete reveal divergence of centromere features in Stramenopila-Alveolata-Rhizaria lineages', 'Fang, Y.; Coelho, M. A.; Shu, H.; Schotanus, K.; Thimmappa, B. C.; Yadav, V.; Chen, H.; Malc, E. P.; Wang, J.; Mieczkowski, P.; Kronmiller, B.; Tyler, B. M.; Sanyal, K.; Dong, S.; Nowrousian, M.; Heitman, J.', 'Joseph  Heitman', 'Duke University', 'microbiology', 'PLOS Genetics', '2019-09-12', '2020-03-09'], [604, '10.1101/579029', '10.1371/journal.pcbi.1007651', 'The Beacon Calculus: A formal method for the flexible and concise modelling of biological systems', 'Boemo, M. A.; Cardelli, L.; Nieduszynski, C. A.', 'Michael A. Boemo', 'Sir William Dunn School of Pathology, University of Oxford', 'systems biology', 'PLOS Computational Biology', '2019-03-16', '2020-03-09'], [605, '10.1101/720631', '10.1371/journal.pcbi.1007669', 'Parallel Tempering with Lasso for Model Reduction in Systems Biology', 'Gupta, S.; Lee, R. E. C.; Faeder, J. R.', 'Sanjana  Gupta', 'University of Pittsburgh', 'systems biology', 'PLOS Computational Biology', '2019-08-01', '2020-03-09'], [606, '10.1101/791483', '10.1371/journal.ppat.1008344', 'Repurposing the Streptococcus mutans CRISPR-Cas9 System to Understand Essential Gene Function', 'Shields, R. C.; Walker, A. R.; Maricic, N.; Underhill, S. A.; Burne, R. A.', 'Robert C Shields', 'University of Florida', 'microbiology', 'PLOS Pathogens', '2019-10-02', '2020-03-09'], [607, '10.1101/409144', '10.1093/gigascience/giaa010', 'Interpretable and accurate prediction models for metagenomics data', 'Prifti, E.; Chevaleyre, Y.; Hanczar, B.; Belda Cuesta, E.; Clement, K.; Danchin, A.; Zucker, J.-D.', 'Jean-Daniel  Zucker', 'Sorbonne University, IRD, UMMISCO, UMI 209, France', 'bioinformatics', 'GigaScience', '2018-09-07', '2020-03-09'], [608, '10.1101/633313', '10.1007/s10479-020-03542-7', 'Operations Research Methods for Estimating the Population Size of Neuron Types', 'Attili, S. M.; Mackesey, S.; Ascoli, G.', 'Sarojini M Attili', 'George Mason University', 'neuroscience', 'Annals of Operations Research', '2019-05-09', '2020-03-09'], [609, '10.1101/784165', '10.1007/s10340-020-01218-6', 'Acute toxicity of the plant volatile indole depends on herbivore specialization', 'Maurya, A. K.; Patel, R. C.; Frost, C. J.', 'Christopher J Frost', 'University of Louisville', 'plant biology', 'Journal of Pest Science', '2019-09-26', '2020-03-09'], [610, '10.1101/694745', '10.1002/csc2.20093', 'Image-based Phenotyping and Genetic Analysis of Potato Skin Set and Color', 'Caraza-Harter, M. V.; Endelman, J. B.', 'Jeffrey B Endelman', 'University of Wisconsin-Madison', 'genetics', 'Crop Science', '2019-07-08', '2020-03-09'], [611, '10.1101/2020.02.19.956581', '10.1016 ...
# [[700, '10.1101/820217', '10.1021/acscentsci.9b01196', 'Live-Cell Imaging and Quantification of PolyQ Aggregates by Stimulated Raman Scattering of Selective Deuterium Labeling', 'Miao, K.; Wei, L.', 'Lu  Wei', 'Caltech', 'biophysics', 'ACS Central Science', '2019-10-28', '2020-03-06'], [701, '10.1101/2020.01.21.913749', '10.1080/15476286.2020.1733798', 'Production and Purification of Endogenously Modified tRNA-Derived Small RNAs', 'Drino, A.; Oberbauer, V.; Troger, C.; Janisiw, E.; Anrather, D.; Hartl, M.; Kaiser, S.; Kellner, S.; Schaefer, M. R.', 'Matthias R. Schaefer', 'Medical University of Vienna', 'biochemistry', 'RNA Biology', '2020-01-21', '2020-03-06'], [702, '10.1101/2020.02.06.937953', '10.1210/endocr/bqaa037', 'A gatekeeping role of ESR2 to maintain the primordial follicle reserve', 'Rumi, M. A.; Chakravarthi, V. P.; Ghosh, S.; Roby, K. F.; Wolfe, M. W.', 'Mohammad A Rumi', 'University of Kansas Medical Center', 'developmental biology', 'Endocrinology', '2020-02-07', '2020-03-06'], [703, '10.1101/607374', '10.1038/s41467-020-14751-w', 'An Analytical Theory of Cellular Growth', 'Dourado, H.; Lercher, M. J.', 'Martin J Lercher', 'Heinrich Heine University', 'biophysics', 'Nature Communications', '2019-04-13', '2020-03-06'], [704, '10.1101/847012', '10.1038/s41598-020-60976-6', 'Verifying molecular clusters by 2-color localization microscopy and significance testing', 'Arnold, A. M.; Schneider, M. C.; Huesson, C.; Sablatnig, R.; Brameshuber, M.; Baumgart, F.; Schuetz, G. J.', 'Gerhard J. Schuetz', 'TU Wien', 'biophysics', 'Scientific Reports', '2019-11-19', '2020-03-06'], [705, '10.1101/849422', '10.1038/s41598-020-61190-0', 'Gene-flow from steppe individuals into Cucuteni-Trypillia associated populations indicates long-standing contacts and gradual admixture', 'Immel, A.; Terna, S.; Simalcsik, A.; Susat, J.; Sarov, O.; Sirbu, G.; Hofmann, R.; Mueller, J.; Nebel, A.; Krause-Kyora, B.', 'Ben  Krause-Kyora', 'Kiel University', 'genomics', 'Scientific Reports', '2019-11-21', '2020-03-06'], [706, '10.1101/707836', '10.1038/s42003-020-0838-z', 'Growth and rapid succession of methanotrophs effectively limit methane release during lake overturn', 'Mayr, M. J.; Zimmermann, M.; Dey, J.; Brand, A.; Buergmann, H.', 'Magdalena J Mayr', 'EAWAG Kastanienbaum, ETH Zurich', 'microbiology', 'Communications Biology', '2019-07-19', '2020-03-06'], [707, '10.1101/809707', '10.1038/s41746-020-0240-8', 'Full-waveform inversion imaging of the human brain', 'Guasch, L.; Calderon Agudo, O.; Tang, M.-X.; Nachev, P.; Warner, M.', 'Lluis  Guasch', 'Department of Earth Science and Engineering, Imperial College London', 'neuroscience', 'npj Digital Medicine', '2019-10-18', '2020-03-06'], [708, '10.1101/2019.12.20.885350', '10.1104/pp.19.01550', 'Compensatory guaiacyl lignin biosynthesis at the expense of syringyl lignin in 4CL1-knockout poplar', 'Tsai, C.-J.; Xu, P.; Xue, L.-J.; Hu, H.; Nyamdari, B.; Naran, R.; Zhou, X.; Goeminne, G.; Gao, R.; Gjersing, E.; Dahlen, J.; Pattathil, S.; Hahn, M. G.; Davis, M.; Ralph, J.; Boerjan, W. A.; Harding, S. A.', 'Chung-Jui  Tsai', 'University of Georgia', 'plant biology', 'Plant Physiology', '2019-12-20', '2020-03-06'], [709, '10.1101/735217', '10.1021/acsinfecdis.0c00016', 'Combined efficacy of a novel antimicrobial cationic peptide polymer with conventional antibiotics to combat multi-drug resistant pathogens', 'Thappeta, K. R.; Vikhe, Y. S.; Yong, A. M. H.; Chan-Park, M.; Kline, K. A.', 'Kimberly A  Kline', 'Nanyang Technological University', 'microbiology', 'ACS Infectious Diseases', '2019-08-14', '2020-03-06'], [710, '10.1101/823187', '10.1002/cne.24898', 'Differential expression of five prosomatostatin genes in the central nervous system of the catshark Scyliorhinus canicula', 'Sobrido-Camean, D.; Tostivint, H.; Mazan, S.; Rodicio, M. C.; Rodriguez-Moldes, I.; Candal, E.; Anadon, R.; Barreiro-Iglesias, A.', 'Anton  Barreiro-Iglesias', 'Universidade de Santiago de Compostela', 'neuroscience', 'Journal of  ...
# journal_list: 100
# [[800, '10.1101/2020.01.13.904581', '10.1021/acs.biochem.0c00035', 'A binary arginine methylation switch on histone H3 Arginine 2 regulates its interaction with WDR5', 'Lorton, B. M.; Harijan, R. K.; Burgos, E. S.; Bonnano, J. B.; Almo, S. C.; Shechter, D.', 'David  Shechter', 'Albert Einstein College of Medicine', 'biochemistry', 'Biochemistry', '2020-01-14', '2020-03-31'], [801, '10.1101/438812', '10.1016/j.celrep.2020.02.078', 'ALS mice carrying pathological mutant TDP-43, but not mutant FUS, display axonal transport defects in vivo', 'Sleigh, J. N.; Tosolini, A. P.; Gordon, D.; Devoy, A.; Fratta, P.; Fisher, E. M.; Talbot, K.; Schiavo, G.', 'James N Sleigh', 'University College London - Institute of Neurology', 'neuroscience', 'Cell Reports', '2018-10-09', '2020-03-17'], [802, '10.1101/663385', '10.1038/s41551-020-0526-9', 'PARP1 as a biomarker for early detection and intraoperative tumor delineation in epithelial cancers - first-in-human results', 'Kossatz, S.; Pirovano, G.; Demetrio De Souza Franca, P.; Strome, A. L.; Sunny, S. P.; Karassawa Zanoni, D.; Mauguen, A.; Carney, B.; Brand, C.; Shah, V.; Ramanajinappa, R. D.; Hedne, N.; Birur, P.; Sihag, S.; Ghossein, R. A.; Gonen, M.; Strome, M.; Suresh, A.; Molena, D.; Kuriakose, M. A.; Patel, S. G.; Reiner, T.', 'Thomas  Reiner', 'Memorial Sloan Kettering Cancer Center', 'clinical trials', 'Nature Biomedical Engineering', '2019-06-14', '2020-03-12'], [803, '10.1101/612515', '10.1038/s41467-020-15084-4', 'Regardless of the deposition pathway, aminoacid 31 in histone variant H3 is essential at gastrulation in Xenopus', 'Sitbon, D.; Boyarchuk, E.; Almouzni, G.', 'Genevieve  Almouzni', 'Institut Curie', 'developmental biology', 'Nature Communications', '2019-04-17', '2020-03-09'], [804, '10.1101/679282', '10.1186/s13229-020-00326-5', 'Salivary sex hormone levels following oxytocin administration in autistic and typical women', 'Procyshyn, T. L.; Lombardo, M. V.; Lai, M.-C.; Auyeung, B.; Crockford, S. K.; Deakin, J.; Soubramanian, S.; Sule, A.; Baron-Cohen, S.; Bethlehem, R. A.', 'Tanya L Procyshyn', 'Department of Psychiatry, University of Cambridge', 'neuroscience', 'Molecular Autism', '2019-06-21', '2020-03-18'], [805, '10.1101/709113', '10.1093/gigascience/giaa022', 'PEMA: from the raw .fastq files of 16S rRNA and COI marker genes to the (M)OTU-table, a thorough metabarcoding analysis', 'Zafeiropoulos, H.; Viet, H. Q.; Vasileiadou, K.; Potirakis, A.; Arvanitidis, C.; Topalis, P.; Pavloudi, C.; Pafilis, E.', 'Haris  Zafeiropoulos', 'IMBBC-HCMR', 'bioinformatics', 'GigaScience', '2019-07-20', '2020-03-12'], [806, '10.1101/664946', '10.1016/j.neuron.2020.02.005', 'Network Synchronization and Synchrony Propagation:Emergent Elements of Inspiration', 'Ashhad, S.; Feldman, J. L.', 'Jack L Feldman', 'University of California Los Angeles', 'neuroscience', 'Neuron', '2019-06-10', '2020-03-03'], [807, '10.1101/317503', '10.1038/s41467-019-14198-8', 'Molecularly distinct astrocyte subpopulations spatially pattern the adult mouse brain', 'Batiuk, M.; Martirosyan, A.; Voet, T.; Ponting, C.; Belgard, T. G.; Holt, M. G.', 'Matthew G. Holt', 'Laboratory of Glia Biology, KU Leuven Department of Neuroscience, Leuven, Belgium', 'neuroscience', 'Nature Communications', '2018-05-10', '2020-03-05'], [808, '10.1101/2020.01.20.913327', '10.1109/TNSRE.2020.2980223', 'How Sensitive are EEG Results to Preprocessing Methods: A Benchmarking Study', 'Robbins, K.; Touryan, J. O.; Mullen, T.; Kothe, C.; Bigdely-Shamlo, N.', 'Kay  Robbins', 'University of Texas at San Antonio', 'neuroscience', 'IEEE Transactions on Neural Systems and Rehabilitation Engineering', '2020-01-21', '2020-03-26'], [809, '10.1101/601039', '10.1016/j.celrep.2020.02.080', 'Cancer cells resist mechanical destruction in the circulation via RhoA-myosin II axis', 'Moose, D. L.; Krog, B. L.; Zhao, L.; Kim, T.-H.; Williams-Perez, S.; Burke, G.; Rhodes, L.; Vanneste, M.; Breheny, P.; Milhem, M.; Stipp, C. S.; Rowat, A. C.; Henry, M. D.', 'Mi ...
#
# journal_list: 100
# [[900, '10.1101/353334', '10.7717/peerj.8797', 'Pan-cancer systematic identification of lncRNAs associated with cancer prognosis', 'Ung, M.; Schaafsma, E.; Mattox, D.; Wang, G.; Cheng, C.', 'Chao  Cheng', 'Dartmouth', 'cancer biology', 'PeerJ', '2018-06-21', '2020-03-24'], [901, '10.1101/682781', '10.1093/bioinformatics/btaa202', 'HiChIP-Peaks: A HiChIP peak calling algorithm', 'Shi, C.; Rattray, M.; Orozco, G.', 'Chenfu  Shi', 'The University of Manchester', 'bioinformatics', 'Bioinformatics', '2019-06-27', '2020-03-19'], [902, '10.1101/608869', '10.1093/bioinformatics/btaa201', 'Resolving single-cell heterogeneity from hundreds of thousands of cells through sequential hybrid clustering and NMF', 'Venkatasubramanian, M.; Chetal, K.; Atluri, G.; Salomonis, N.', 'Nathan  Salomonis', "Division of Biomedical Informatics, Cincinnati Children's Hospital Medical Center, Cincinnati, OH", 'bioinformatics', 'Bioinformatics', '2019-04-14', '2020-03-19'], [903, '10.1101/681726', '10.1038/s41467-020-15351-4', 'Dimensionality reduction by UMAP to visualize physical and genetic interactions', 'Dorrity, M. W.; Saunders, L. M.; Queitsch, C.; Fields, S.; Trapnell, C.', 'Cole  Trapnell', 'University of Washington', 'genomics', 'Nature Communications', '2019-06-25', '2020-03-24'], [904, '10.1101/565283', '10.1038/s41467-020-15321-w', 'Polychromatic solar energy conversion in pigment-protein chimeras that unite the two kingdoms of (bacterio)chlorophyll-based photosynthesis', 'Liu, J.; Friebe, V. M.; Frese, R. N.; Jones, M. R.', 'Michael R. Jones', 'University of Bristol', 'synthetic biology', 'Nature Communications', '2019-03-04', '2020-03-24'], [905, '10.1101/636860', '10.1038/s41598-020-62201-w', 'Fluorescent Sp3 Defect-Tailored Carbon Nanotubes Enable NIR-II Single Particle Imaging in Live Brain Slices at Ultra-Low Excitation Doses', 'Mandal, A. K.; Wu, X.; Ferreira, J. S.; Kim, M.; Powell, L. R.; Kwon, H.; Groc, L.; Wang, Y.; Cognet, L.', 'Laurent  Cognet', 'Univ. Bordeaux - CNRS', 'biophysics', 'Scientific Reports', '2019-05-15', '2020-03-24'], [906, '10.1101/638866', '10.1038/s41598-020-62279-2', 'OncoOmics approaches to reveal essential genes in breast cancer: a panoramic view from pathogenesis to precision medicine', 'Lopez-Cortes, A.; Paz-y-Mino, C.; Guerrero, S.; Cabrera-Andrade, A.; Barigye, S. J.; Munteanu, C. R.; Gonzalez-Diaz, H.; Pazos, A.; Perez-Castillo, Y.; Tejera, E.', 'Andres  Lopez-Cortes', 'Universidad UTE', 'genomics', 'Scientific Reports', '2019-05-16', '2020-03-24'], [907, '10.1101/772640', '10.7554/eLife.51453', 'Polyunsaturated fatty acid analogues differentially affect cardiac Nav, Cav, and Kv channels through unique mechanisms', 'Bohannon, B.; Wu, X.; Perez, M.; Liin, S. I.; Larsson, H. P.', 'H Peter  Larsson', 'University of Miami', 'biophysics', 'eLife', '2019-09-19', '2020-03-24'], [908, '10.1101/777615', '10.7554/eLife.52224', 'Deciphering anomalous heterogeneous intracellular transport with neural networks', 'Han, D. S.; Korabel, N.; Chen, R.; Johnston, M.; Allan, V. J.; Fedotov, S.; Waigh, T. A.', 'Daniel S Han', 'University of Manchester', 'cell biology', 'eLife', '2019-09-23', '2020-03-24'], [909, '10.1101/852962', '10.7554/eLife.53684', 'Correcting for physical distortions in visual stimuli improves reproducibility in zebrafish neuroscience.', 'Dunn, T. W.; Fitzgerald, J. E.', 'James E  Fitzgerald', 'Janelia Research Campus, Howard Hughes Medical Institute', 'neuroscience', 'eLife', '2019-11-25', '2020-03-24'], [910, '10.1101/759241', '10.1128/MCB.00628-19', 'Growth-regulated Hsp70 phosphorylation regulates stress responses and prion maintenance', 'Kao, C.-H.; Ryu, S.; Kim, M. J.; Wen, X.; Wimalarathne, O.; Paull, T. T.', 'Tanya T.  Paull', 'The University of Texas at Austin', 'molecular biology', 'Molecular and Cellular Biology', '2019-09-05', '2020-03-24'], [911, '10.1101/742387', '10.1016/j.chom.2020.02.015', 'Altered immunity of laboratory mice in the natural environment is associated with fungal coloniza ...
# journal_list: 100
# [[1000, '10.1101/242933', '10.1038/s41598-020-62621-8', 'Differential regulation of microRNA-15a by radiation affects angiogenesis and tumor growth via modulation of acid sphingomyelinase', 'Rana, S.; Espinosa-Diez, C.; Ruhl, R.; Thomas, C. R.; Anand, S.', 'Sudarshan  Anand', 'OHSU', 'cancer biology', 'Scientific Reports', '2018-01-04', '2020-03-27'], [1001, '10.1101/2020.01.23.917666', '10.3389/fbioe.2020.00204', 'Enhancing CO2-valorization using Clostridium autoethanogenum for sustainable fuel and chemicals production', 'Heffernan, J. K.; Valgepea, K.; Lemgruber, R. d. S. P.; Casini, I.; Plan, M.; Tappel, R.; Simpson, S. D.; Koepke, M.; Nielsen, L. K.; Marcellin, E.', 'Esteban  Marcellin', 'The University of Queensland', 'bioengineering', 'Frontiers in Bioengineering and Biotechnology', '2020-01-24', '2020-03-27'], [1002, '10.1101/269720', '10.12688/f1000research.22242.1', 'AlignmentViewer: Sequence Analysis of Large Protein Families', 'Reguant, R.; Antipin, Y.; Sheridan, R.; Luna, A.; Sander, C.', 'Roc  Reguant', 'Department of Cell Biology, Harvard Medical School', 'bioinformatics', 'F1000Research', '2018-02-22', '2020-03-27'], [1003, '10.1101/2020.01.13.904185', '10.7554/eLife.54937', 'A calibrated optogenetic toolbox of stable zebrafish opsin lines', 'Antinucci, P.; Dumitrescu, A.; Deleuze, C.; Morley, H. J.; Leung, K.; Hagley, T.; Kubo, F.; Baier, H.; Bianco, I. H.; Wyart, C.', 'Claire  Wyart', 'Institut du Cerveau et la Moelle épinière, Hôpital Pitié-Salpêtrière, Sorbonne Universités, UPMC Univ Paris 06, Inserm, CNRS', 'neuroscience', 'eLife', '2020-01-15', '2020-03-27'], [1004, '10.1101/424929', '10.7554/eLife.53060', 'Optimization of Energy State Transition Trajectory Supports the Development of Executive Function During Youth', 'Cui, Z.; Stiso, J.; Baum, G. L.; Kim, J. Z.; Roalf, D. R.; Betzel, R. F.; Gu, S.; Lu, Z.; Xia, C. H.; Ciric, R.; Moore, T. M.; Shinohara, R. T.; Ruparel, K.; Davatzikos, C.; Pasqualetti, F.; Gur, R. E.; Gur, R. C.; Bassett, D. S.; Satterthwaite, T. D.', 'Theodore D Satterthwaite', 'University of Pennsylvania', 'neuroscience', 'eLife', '2018-09-23', '2020-03-27'], [1005, '10.1101/569335', '10.7554/eLife.47003', 'Reducing RSV hospitalisation in a lower-income country by vaccinating mothers-to-be and their households', 'Brand, S. P. C.; Munywoki, P.; Walumbe, D.; Keeling, M. J.; Nokes, D. J.', 'Samuel P C Brand', 'University of Warwick', 'epidemiology', 'eLife', '2019-03-08', '2020-03-27'], [1006, '10.1101/2019.12.24.887679', '10.7554/eLife.55007', 'Unc-4 acts to promote neuronal identity and development of the take-off circuit in the Drosophila CNS', 'Lacin, H.; Williamson, W. R.; Card, G. M.; Skeath, J. B.; Truman, J. W.', 'Haluk  Lacin', 'Washington University School of Medicine', 'developmental biology', 'eLife', '2019-12-24', '2020-03-27'], [1007, '10.1101/2020.02.05.935734', '10.1186/s42483-020-00048-9', 'Silicon modulates multi-layered defense against powdery mildew in Arabidopsis', 'Wang, L.; Dong, M.; Zhang, Q.; Wu, Y.; Hu, L.; Parson, J. F.; Eisenstein, E.; Du, X.; Xiao, S.', 'Shunyuan  Xiao', 'University of Maryland, College Park', 'plant biology', 'Phytopathology Research', '2020-02-06', '2020-03-27'], [1008, '10.1101/556381', '10.1039/C9SM02413A', 'Programmable patterns in a DNA-based reaction-diffusion system', 'Chen, S.; Seelig, G.', 'Georg  Seelig', 'University of Washington', 'synthetic biology', 'Soft Matter', '2019-02-21', '2020-03-27'], [1009, '10.1101/665810', '10.1242/dev.183715', 'The Arabidopsis Diacylglycerol Kinase 4 is involved in nitric oxide-dependent pollen tube guidance and fertilization', 'Wong, A.; Donaldson, L.; Portes, M. T.; Eppinger, J.; Feijo, J.; Gehring, C.', 'José  Feijó', 'University of Maryland', 'plant biology', 'Development', '2019-06-09', '2020-03-27'], [1010, '10.1101/661629', '10.1093/aje/kwaa049', 'The impact of delayed switch to second-line antiretroviral therapy on mortality, depending on failure time definition and CD4 count at failure', 'Bell ...
# journal_list: 100
# ...
# journal_list: 100
# [[1400, '10.1101/544718', '10.1523/eneuro.0297-19.2020', "Deficit in motor skill learning-dependent synaptic plasticity at motor cortex to Dorso Lateral Striatum synapses in a mouse model of Huntington's disease", 'Glangetas, C.; Espinosa, P.; Bellone, C.', 'Camilla  Bellone', 'Department of Basic Neuroscience, University of Geneva', 'neuroscience', 'eneuro', '2019-02-08', '2020-03-06'], [1401, '10.1101/669556', '10.1371/journal.pone.0218840', 'Socio-demographic correlates and clustering of Non-Communicable Diseases risk factors among reproductive aged women of Nepal: Results from Nepal Demographic Health Survey 2016', 'Bista, B.; Dhungana, R. R.; Chalise, B.; Pandey, A. R.', 'Bihungum  Bista', 'Nepal Health Research Council', 'epidemiology', 'PLOS ONE', '2019-06-12', '2020-03-16'], [1402, '10.1101/701250', '10.1126/sciadv.aaz1588', 'A reconstituted mammalian APC-kinesin complex selectively transports defined packages of axonal mRNAs', 'Baumann, S.; Komissarov, A.; Gili, M. L.; Ruprecht, V.; Wieser, S.; Maurer, S. P.', 'Sebastian P Maurer', 'Center for Genomic Regulation (CRG)', 'biochemistry', 'Science Advances', '2019-07-26', '2020-03-13'], [1403, '10.1101/731380', '10.1098/rsos.192068', 'Rough substrates constrain walking speed in ants through modulation of stride frequency and not stride length', 'Clifton, G.; Holway, D.; Gravish, N.', 'Nick  Gravish', 'University of California San Diego', 'biophysics', 'Royal Society Open Science', '2019-08-13', '2020-03-25'], [1404, '10.1101/740183', '10.1371/journal.pone.0221842', 'Freshwater soundscapes: a cacophony of undescribed biological sounds now threatened by anthropogenic noise', 'Rountree, R. A.; Juanes, F.; Bolgan, M.', 'Rodney  A.  Rountree', 'The Fish Listener', 'ecology', 'PLOS ONE', '2019-08-19', '2020-03-18'], [1405, '10.1101/726349', '10.1155/2020/5138539', 'Nrf1 is endowed with a dominant tumor-repressing effect onto the Wnt/β-Catenin-dependent and -independent signaling networks in the human liver cancer', 'Chen, J.; Wang, M.; Ru, X.; Xiang, Y.; Ren, Y.; Liu, X.; Qiu, L.; Zhang, Y.', 'Yiguo  Zhang', 'Chongqing University', 'cancer biology', 'Oxidative Medicine and Cellular Longevity', '2019-08-05', '2020-03-23'], [1406, '10.1101/626184', '10.7717/peerj.8635', 'Investigation of cellular stress response related heat shock protein hsp70/Hsp70 and multixenobiotic transporter abcb1 in Siberian freshwater amphipods upon cadmium exposure', 'Protopopova, M. V.; Pavlichenko, V. V.; Luckenbach, T.', 'Till  Luckenbach', 'Helmholtz Centre for Environmental Research - UFZ', 'zoology', 'PeerJ', '2019-05-02', '2020-03-09'], [1407, '10.1101/591628', '10.1242/dev.186957', 'Oriented basement membrane fibrils provide a memory for F-actin planar polarization via the Dystrophin-Dystroglycan complex during tissue elongation', 'Cerqueira Campos, F.; Alegot, H.; Dennis, C.; Fritsch, C.; Isabella, A.; Pouchin, P.; Bardot, O.; Horne-Badovinac, S.; Mirouse, V.', 'Vincent  Mirouse', 'GReD', 'developmental biology', 'Development', '2019-03-30', '2020-03-10'], [1408, '10.1101/703231', '10.1371/journal.pone.0220268', 'Similarity of species composition of sand flies (Diptera: Psychodidae) in caves of Quadrilatero Ferrifero, state Minas Gerais, Brasil', 'Campos, A. M.; Maia, R. A.; Capucci, D.; Paglia, A. P.; Andrade Filho, J. D.', 'José Dilermando  Andrade Filho', 'Centro de Pesquisas René Rachou/Fundação Oswaldo Cruz', 'zoology', 'PLOS ONE', '2019-07-15', '2020-03-10'], [1409, '10.1101/669721', '10.1371/journal.pgen.1008241', 'Disentangling group specific QTL allele effects from genetic background epistasis using admixed individuals in GWAS: an application to maize flowering', 'Rio, S.; Mary-Huard, T.; Laurence, M.; Bauland, C.; Carinne, P.; Delphine, M.; Combes, V.; Alain, C.', 'Simon  Rio', 'INRA', 'genetics', 'PLOS Genetics', '2019-06-12', '2020-03-04'], [1410, '10.1101/783621', '10.1038/s41598-020-62354-8', 'Differential stromal reprogramming in benign and malignant naturally occurring canine m ...
# journal_list: 79
# [[1500, '10.1101/630343', '10.1002/aur.2289', 'Neural correlates of cardiac interoceptive accuracy across development: implications for social symptoms in autism spectrum disorders', 'Failla, M. D.; Bryant, L. K.; Heflin, B. H.; Mash, L. E.; Schauder, K.; Davis, S.; Gerdes, M. B.; Weitlauf, A. S.; Rogers, B. P.; Cascio, C. J.', 'Carissa J. Cascio', 'Vanderbilt University Medical Center', 'neuroscience', 'Autism Research', '2019-05-07', '2020-03-05'], [1501, '10.1101/542613', '10.1093/ije/dyaa005', 'Descriptive epidemiology of energy expenditure in the UK: Findings from the National Diet and Nutrition Survey 2008 to 2015', 'Brage, S.; Lindsay, T.; Venables, M.; Wijndaele, K.; Westgate, K.; Collins, D.; Bluck, L.; Wareham, N.; Page, P.', 'Soren  Brage', 'MRC Epidemiology Unit, University of Cambridge, United Kingdom', 'epidemiology', 'International Journal of Epidemiology', '2019-02-08', '2020-03-19'], [1502, '10.1101/689463', '10.1111/1365-2664.13595', 'Evaluating the ecological impacts of pesticide seed treatments on arthropod communities in a grain crop rotation', 'Dubey, A.; Lewis, M.; Dively, G.; Hamby, K.', 'Aditi  Dubey', 'University of Maryland College Park', 'ecology', 'Journal of Applied Ecology', '2019-07-02', '2020-03-22'], [1503, '10.1101/557801', '10.1016/j.cmet.2020.01.014', 'Short-term consumption of sucralose with, but not without, carbohydrate impairs neural and metabolic sensitivity to sugar', 'Dalenberg, J. R.; Patel, B. P.; Denis, R.; Veldhuizen, M. G.; Nakamura, Y.; Vinke, P. C.; Luquet, S.; Small, D. M.', 'Dana M.  Small', 'Yale University School of Medicine', 'physiology', 'Cell Metabolism', '2019-02-22', '2020-03-03'], [1504, '10.1101/2019.12.17.879924', '10.1186/s40478-020-00897-7', 'Astrocytes improve neuronal health after cisplatin treatment through mitochondrial transfer.', 'English, K.; Shepherd, A.; Nzor, N.-E.; Trinh, R.; Kavelaars, A.; Heijnen, C.', 'Cobi  Heijnen', 'University of Texas MD Anderson Cancer Center', 'neuroscience', 'Acta Neuropathologica Communications', '2019-12-18', '2020-03-20'], [1505, '10.1101/784884', '10.1002/cpcy.70', 'Design and Optimization Protocol for High-Dimensional Immunophenotyping Assays using Spectral Flow Cytometry', 'Ferrer-Font, L.; Pellefigues, C.; Mayer, J. U.; Small, S.; Jaimes, M. C.; Price, K. M.', 'Laura  Ferrer-Font', 'Malaghan Institute of Medical Research', 'immunology', 'Current Protocols in Cytometry', '2019-09-27', '2020-03-05'], [1506, '10.1101/512301', '10.1371/journal.ppat.1008386', 'Molecular basis of P major human rotavirus VP8* domain interactions with histo-blood group antigens', 'Xu, S.; Liu, Y.; Tan, M.; Zhong, W.; Zhao, D.; Jiang, X.; Kennedy, M. A.', 'Michael  A  Kennedy', 'Miami University', 'biochemistry', 'PLOS Pathogens', '2019-01-04', '2020-03-24'], [1507, '10.1101/554618', '10.1002/ajpa.24041', 'Intra- and Inter-Specific Investigations of Skeletal DNA Methylation Patterns and Femur Morphology in Nonhuman Primates', 'Housman, G.; Quillen, E. E.; Stone, A. C.', 'Genevieve  Housman', 'Arizona State University', 'genomics', 'American Journal of Physical Anthropology', '2019-02-19', '2020-03-14'], [1508, '10.1101/763094', '10.1371/journal.pone.0222738', 'Accuracy of serological tests for diagnosis of chronic pulmonary aspergillosis: a systematic review and meta-analysis', 'VOLPE CHAVES, C. E.; DO VALLE LEONE DE OLIVEIRA, S. M.; VENTURINI, J.; GRANDE, A. J.; SYLVESTRE, T. F.; PONCIO MENDES, R.; MELLO MIRANDA PANIAGO, A.', 'CLÁUDIA ELIZABETH  VOLPE CHAVES', 'Federal University of Mato Grosso do Sul (UFMS)', 'pathology', 'PLOS ONE', '2019-09-09', '2020-03-17'], [1509, '10.1101/671230', '10.1038/s41556-020-0485-0', 'Phase separation of TAZ compartmentalizes the transcription machinery to promote gene expression', 'Wu, T.; Lu, Y.; Gutman, O.; Lu, H.; Zhou, Q.; Henis, Y. I.; Luo, K.', 'Kunxin  Luo', 'Department of Molecular and Cell Biology, University of California, Berkeley', 'cell biology', 'Nature Cell Biology', '2019-06-14', '2020-03-23'] ...
#              pre_DOI                           pub_DOI  \
# 0     10.1101/759530            10.1101/gad.332643.119
# 1     10.1101/843441          10.3389/fnins.2020.00182
# 2     10.1101/681353         10.1038/s41593-020-0603-0
# 3     10.1101/796433  10.1016/j.neuroimage.2020.116698
# 4     10.1101/838573           10.1111/1462-2920.14966
# ...              ...                               ...
# 1574  10.1101/588392        10.1007/s10815-020-01725-6
# 1575  10.1101/653675                 10.1111/jeb.13608
# 1576  10.1101/761106             10.15252/msb.20199083
# 1577  10.1101/774265        10.1038/s41467-020-15457-9
# 1578  10.1101/643056           10.1073/pnas.1910141117
#
#                                                   Title  \
# 0     Senolytic treatment targets aberrant p21-expre...
# 1     Functional Connectivity Evoked by Orofacial Ta...
# 2     Connecting gene regulatory relationships to ne...
# 3     Intersubject consistent dynamic connectivity d...
# 4     Genome Repository of Oiled Systems (GROS): an ...
# ...                                                 ...
# 1574  Ontogeny and expression profiles of steroid ho...
# 1575  The evolution of parasite host range in geneti...
# 1576  KDML: a machine-learning framework for inferen...
# 1577  Identification of gut microbiome markers for s...
# 1578  Mitochondrial DNA has strong selective effects...
#
#                                                 Authors  \
# 0     Ritschka, B.; Knauer-Meyer, T.; Mas, A.; Plass...
# 1     Wang, Y.; Sibaii, F.; Custead, R.; Oh, H.; Bar...
# 2             Sey, N. Y. A.; Fauni, H.; Ma, W.; Won, H.
# 3                                 Di, X.; Biswal, B. B.
# 4     Karthikeyan, S.; Rodriguez-R, L. M.; Heritier-...
# ...                                                 ...
# 1574  Mishra, A.; Galvankar, M.; Singh, N.; Vaidya, ...
# 1575  Gibson, A. K.; Baffoe-Bonnie, H. S.; Penley, M...
# 1576            Sailem, H.; Rittscher, J.; Pelkmans, L.
# 1577  Zhu, F.; Ju, Y.; Wang, W.; Wang, Q.; Guo, R.; ...
# 1578                        Healy, T. M.; Burton, R. S.
#
#                Corresponding_Authors  \
# 0                   William M. Keyes
# 1                     Yingying  Wang
# 2                       Hyejung  Won
# 3                    Bharat B Biswal
# 4     Konstantinos T  Konstantinidis
# ...                              ...
# 1574                    Deepak  Modi
# 1575              Amanda Kyle Gibson
# 1576                    Heba  Sailem
# 1577                     Huijue  Jia
# 1578                 Timothy M Healy
#
#                                             Institution              Category  \
# 0                                                 IGBMC          cell biology
# 1                        University of Nebraska-Lincoln          neuroscience
# 2             University of North Carolina- Chapel Hill          neuroscience
# 3                    New Jersey Institute of Technology          neuroscience
# 4                       Georgia Institute of Technology              genomics
# ...                                                 ...                   ...
# 1574  ICMR-National Institute for Research in Reprod...             pathology
# 1575                             University of Virginia  evolutionary biology
# 1576                               University of Oxford       systems biology
# 1577                                       BGI-Shenzhen          microbiology
# 1578  Scripps Institution of Oceanography, Universit...  evolutionary biology
#
#                                               Journal Preprint_Date  \
# 0                                 Genes & Development    2019-09-05
# 1                           Frontiers in Neuroscience    2019-11-16
# 2                                 Nature Neuroscience    2019-06-24
# 3                                          NeuroImage    2019-10-07
# 4                          Environmental Microbiology    2019-11-12
# ...                                               ...           ...
# 1574    Journal of Assisted Reproduction and Genetics    2019-03-25
# 1575                  Journal of Evolutionary Biology    2019-05-29
# 1576                        Molecular Systems Biology    2019-09-08
# 1577                            Nature Communications    2019-09-19
# 1578  Proceedings of the National Academy of Sciences    2019-05-20
#
#      Published_Date  Num_of_Authors
# 0        2020-03-05              10
# 1        2020-03-06               5
# 2        2020-03-09               4
# 3        2020-03-01               2
# 4        2020-03-02               7
# ...             ...             ...
# 1574     2020-03-09               6
# 1575     2020-03-09               7
# 1576     2020-03-06               3
# 1577     2020-03-31              18
# 1578     2020-03-10               2
#
# [1579 rows x 11 columns]

# %%
#summary of table
pubs_df.describe(include='all')
# Out:
# <ipython-input-11-edaec0628958>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   pubs_df.describe(include='all')
#                pre_DOI                pub_DOI  \
# count             1579                   1579
# unique            1579                   1578
# top     10.1101/759530  10.1534/g3.120.401151
# freq                 1                      2
# first              NaN                    NaN
# last               NaN                    NaN
# mean               NaN                    NaN
# std                NaN                    NaN
# min                NaN                    NaN
# 25%                NaN                    NaN
# 50%                NaN                    NaN
# 75%                NaN                    NaN
# max                NaN                    NaN
#
#                                                     Title  \
# count                                                1579
# unique                                               1579
# top     Senolytic treatment targets aberrant p21-expre...
# freq                                                    1
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   Authors  \
# count                                                1579
# unique                                               1579
# top     Ritschka, B.; Knauer-Meyer, T.; Mas, A.; Plass...
# freq                                                    1
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Corresponding_Authors           Institution      Category   Journal  \
# count                   1579                  1579          1579      1579
# unique                  1559                  1119            27       540
# top         Jackson  Champer  University of Oxford  neuroscience  PLOS ONE
# freq                       3                    18           280        97
# first                    NaN                   NaN           NaN       NaN
# last                     NaN                   NaN           NaN       NaN
# mean                     NaN                   NaN           NaN       NaN
# std                      NaN                   NaN           NaN       NaN
# min                      NaN                   NaN           NaN       NaN
# 25%                      NaN                   NaN           NaN       NaN
# 50%                      NaN                   NaN           NaN       NaN
# 75%                      NaN                   NaN           NaN       NaN
# max                      NaN                   NaN           NaN       NaN
#
#               Preprint_Date       Published_Date  Num_of_Authors
# count                  1579                 1579     1579.000000
# unique                  492                   31             NaN
# top     2019-09-19 00:00:00  2020-03-03 00:00:00             NaN
# freq                     17                   92             NaN
# first   2016-06-13 00:00:00  2020-03-01 00:00:00             NaN
# last    2020-03-29 00:00:00  2020-03-31 00:00:00             NaN
# mean                    NaN                  NaN        7.029132
# std                     NaN                  NaN        5.184960
# min                     NaN                  NaN        1.000000
# 25%                     NaN                  NaN        4.000000
# 50%                     NaN                  NaN        6.000000
# 75%                     NaN                  NaN        9.000000
# max                     NaN                  NaN       46.000000

# %%
#freq count of Num_of_Authors
freq_count(pubs_df,'Num_of_Authors')
# Out:
# 3     192
# 5     186
# 4     185
# 6     176
# 7     148
# 2     141
# 8     118
# 9      87
# 10     64
# 11     53
# 13     35
# 12     29
# 1      26
# 14     25
# 15     24
# 16     19
# 17     13
# 18     11
# 21     10
# 22      6
# 19      4
# 26      4
# 30      3
# 24      2
# 31      2
# 20      2
# 46      1
# 43      1
# 41      1
# 34      1
# 28      1
# 32      1
# 40      1
# 25      1
# 45      1
# 29      1
# 27      1
# 33      1
# 44      1
# 38      1
# Name: Num_of_Authors, dtype: int64

# %%
#freq count "Corresponding_Authors"
freq_count(pubs_df, 'Corresponding_Authors')
# Out:
# Jackson  Champer     3
# Sudha  Rajamani      2
# James A. Wells       2
# Harshad  Ghodke      2
# Kevin B Wood         2
#                     ..
# Natalia  Ninkina     1
# Pranav  Danthi       1
# Alexander  Lorenz    1
# Chong  Zhang         1
# Timothy M Healy      1
# Name: Corresponding_Authors, Length: 1559, dtype: int64

# %%
#freq_count Institution
freq_count(pubs_df, 'Institution')
# Out:
# University of Oxford                                                                                                                                          18
# Stanford University                                                                                                                                           16
# University of Pennsylvania                                                                                                                                    12
# University of California, Berkeley                                                                                                                            11
# Harvard University                                                                                                                                            11
#                                                                                                                                                               ..
# Institut de Recherche Experimentale et Clinique (IREC), Pole of Pharmacology and Therapeutics (FATH), Universite Catholique de Louvain, Brussels, Belgium.     1
# Institut de Systematique, Evolution, Biodiversite (ISYEB), Museum national d'histoire naturelle                                                                1
# Institut du Cerveau et la Moelle épinière, Hôpital Pitié-Salpêtrière, Sorbonne Universités, UPMC Univ Paris 06, Inserm, CNRS                                   1
# Institut fuer Populationsgenetik, Vetmeduni Vienna                                                                                                             1
# École polytechnique fédérale de Lausanne                                                                                                                       1
# Name: Institution, Length: 1119, dtype: int64

# %%
#freq_count Category
freq_count(pubs_df, 'Category')
# Out:
# neuroscience                              280
# bioinformatics                            142
# microbiology                              139
# cell biology                               90
# genomics                                   84
# biophysics                                 83
# evolutionary biology                       80
# genetics                                   76
# ecology                                    68
# biochemistry                               62
# plant biology                              61
# cancer biology                             58
# developmental biology                      51
# immunology                                 48
# molecular biology                          47
# systems biology                            36
# bioengineering                             26
# physiology                                 26
# animal behavior and cognition              25
# pharmacology and toxicology                20
# epidemiology                               19
# synthetic biology                          19
# scientific communication and education     18
# pathology                                   8
# zoology                                     7
# clinical trials                             5
# Microbiology                                1
# Name: Category, dtype: int64

# %%
#freq count Jounral
freq_count(pubs_df, 'Journal')
# Out:
# PLOS ONE                                           97
# Scientific Reports                                 74
# eLife                                              64
# Nature Communications                              61
# Proceedings of the National Academy of Sciences    45
#                                                    ..
# Journal of Medical Genetics                         1
# Journal of Mathematical Economics                   1
# Journal of Mammalogy                                1
# Chemical Communications                             1
# ACS Applied Materials & Interfaces                  1
# Name: Journal, Length: 540, dtype: int64

# %%
#freq count Preprint_Date
freq_count(pubs_df, 'Preprint_Date')
# Out:
# 2019-09-19    17
# 2019-10-07    15
# 2019-11-29    15
# 2019-10-10    14
# 2019-09-23    14
#               ..
# 2017-08-01     1
# 2019-05-18     1
# 2018-02-18     1
# 2017-12-29     1
# 2019-05-11     1
# Name: Preprint_Date, Length: 492, dtype: int64

# %%
#freq count Published_date
freq_count(pubs_df, 'Published_Date')
# Out:
# 2020-03-03    92
# 2020-03-09    91
# 2020-03-12    91
# 2020-03-19    79
# 2020-03-17    73
# 2020-03-05    72
# 2020-03-13    71
# 2020-03-06    69
# 2020-03-02    68
# 2020-03-10    68
# 2020-03-04    67
# 2020-03-11    65
# 2020-03-23    64
# 2020-03-18    63
# 2020-03-20    61
# 2020-03-31    60
# 2020-03-16    59
# 2020-03-25    59
# 2020-03-26    58
# 2020-03-30    57
# 2020-03-24    57
# 2020-03-27    40
# 2020-03-14    25
# 2020-03-28    20
# 2020-03-07    14
# 2020-03-29    12
# 2020-03-21    11
# 2020-03-01     6
# 2020-03-22     4
# 2020-03-15     2
# 2020-03-08     1
# Name: Published_Date, dtype: int64

# %%
'''
                      columns=["pre_DOI", "pub_DOI",
                               "Title", "Authors", "Corresponding_Authors",
                               "Institution",
                               "Category", "Journal", "Preprint_Date", "Published_Date"])
'''
assert num_pubs == len(pubs_df)
"Total number of papers published and the length of the dataframe does match."
# Out:
# 'Total number of papers published and the length of the dataframe does match.'

# %%
def get_publisher_prefix(doi: pd.Series) -> pd.Series:
    return doi.apply(lambda x: x.split("/")[0])

query_type='/publisher'

def get_publisher_data(url)
get_data(None,f'{base_url}{query_type}'
         get_publisher_prefix(pubs_df.pub_DOI).unique())
# Out:
# array(['10.1101', '10.3389', '10.1038', '10.1016', '10.1111', '10.1002',
#        '10.1039', '10.3390', '10.1099', '10.1371', '10.1186', '10.1074',
#        '10.1103', '10.7554', '10.1534', '10.1073', '10.1007', '10.1214',
#        '10.1093', '10.1094', '10.15252', '10.1088', '10.1083', '10.1021',
#        '10.1109', '10.1523', '10.1182', '10.5334', '10.1098', '10.1128',
#        '10.1080', '10.26508', '10.1158', '10.1085', '10.1037', '10.1155',
#        '10.1097', '10.1162', '10.1152', '10.1242', '10.1172', '10.1089',
#        '10.1136', '10.1107', '10.1530', '10.1200', '10.1126', '10.7717',
#        '10.2174', '10.1364', '10.1261', '10.3758', '10.1210', '10.1104',
#        '10.2337', '10.1096', '10.1177', '10.1105', '10.7150', '10.12688',
#        '10.1042', '10.18632', '10.1086', '10.3934', '10.4049', '10.1212',
#        '10.1053', '10.34067', '10.1167', '10.1124', '10.1161', '10.1139',
#        '10.1084', '10.1142', '10.2478', '10.4236', '10.1254', '10.4252',
#        '10.2217', '10.5091', '10.3372', '10.2147', '10.3791', '10.1163',
#        '10.3168', '10.1681'], dtype=object)

# %% [markdown]
# **Journal API**<br>
# https://www.nature.com/opensearch/<br>
# https://www.biorxiv.org/content/10.1101/339747v4<br>
# https://www.biorxiv.org/content/10.1101/339747v4.full.pdf<br>
# https://api.biorxiv.org/details/biorxiv/10.1101/099697

# %% [markdown]
# ----

# %% [markdown]
# ### Junk Code
# Please disregard the codes below.

# %%
journal_list = []

# `license`,`abstract`, and `server` are excluded from the metrics. 
for journal in json_info["collection"]:
    journal_list.append([journal["doi"], journal["title"], journal["authors"],
                         journal["author_corresponding"], 
                         journal["author_corresponding_institution"],
                         journal["date"], journal["version"], journal["type"],
                         journal["category"], journal["jatsxml"], journal["published"]])

# %%
journal_df = pd.DataFrame(data=journal_list,
                         columns=["DOI", "Title", "Authors", "Corresponding Authors",
                                  "Institution",
                                  "Date", "Version", "Type", "Category", "Xml", "Published"])
journal_df.head()
# Out:
#               DOI                                              Title  \
# 0  10.1101/402644  Resting shear elastic modulus as a marker of p...
# 1  10.1101/402701  Enterotype-like microbiome stratification as e...
# 2  10.1101/402560  An open-source software analysis package for M...
# 3  10.1101/402586  Over-expression of the photoperiod response re...
# 4  10.1101/402743  A natural history model for planning prostate ...
#
#                                              Authors Corresponding Authors  \
# 0  SIRACUSA, J.; CHARLOT, K.; MALGOYRE, A.; CONOR...      Julien  SIRACUSA
# 1                                      Martin, M. A.  Miguel Angel  Martin
# 2     Harink, B.; Nguyen, H.; Thorn, K.; Fordyce, P.        Polly  Fordyce
# 3  Stephenson, E.; Estrada, S.; Meng, X.; Ourada,...    Olga  Danilevskaya
# 4  Karlsson, A.; Jauhiainen, A.; Gulati, R.; Eklu...     Andreas  Karlsson
#
#                                          Institution        Date Version  \
# 0                                               IRBA  2018-08-28       1
# 1  Universidad Politecnica de Madrid Centro de Es...  2018-08-28       1
# 2                                Stanford University  2018-08-28       1
# 3                                     DuPont Pioneer  2018-08-28       1
# 4                               Karolinska Institute  2018-08-28       1
#
#           Type               Category  \
# 0  new results             physiology
# 1  new results        systems biology
# 2  new results         bioengineering
# 3  new results  developmental biology
# 4  new results           epidemiology
#
#                                                  Xml  \
# 0  https://www.biorxiv.org/content/early/2018/08/...
# 1  https://www.biorxiv.org/content/early/2018/08/...
# 2  https://www.biorxiv.org/content/early/2018/08/...
# 3  https://www.biorxiv.org/content/early/2018/08/...
# 4  https://www.biorxiv.org/content/early/2018/08/...
#
#                       Published
# 0                            NA
# 1     10.1142/S0218348X21502108
# 2  10.1371/journal.pone.0203725
# 3  10.1371/journal.pone.0203728
# 4  10.1371/journal.pone.0211918
