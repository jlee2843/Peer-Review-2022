# %%
import pandas as pd
import numpy as np
import requests
import json
import urllib, urllib.request

# %% [markdown]
# **Biorxiv API** information is found [here](https://api.biorxiv.org/details/medrxiv/help).
# <br>**Final edit:** November 21st, 2022.

# %%
request_API = requests.get("https://api.biorxiv.org/details/biorxiv/2018-08-21/2018-08-28/101")
data = request_API.text
json_info = json.loads(data)

# %%
total = json_info["messages"][0]["total"]
total
# Out:
# 630

# %%
total = json_info["messages"][0]["total"]
current_cursor = 0
journal_list = []

while (current_cursor <= total):
    request_API = requests.get(f"https://api.biorxiv.org/details/biorxiv/2018-08-21/2018-08-28/{current_cursor}")
        
    data = request_API.text
    json_info = json.loads(data)
    
    for journal in json_info["collection"]:
        journal_list.append([journal["doi"], journal["title"], journal["authors"],
                             journal["author_corresponding"], 
                             journal["author_corresponding_institution"],
                             journal["date"], journal["version"], journal["type"],
                             journal["category"], journal["jatsxml"], journal["published"]])
        
    current_cursor += 100

# %%
journal_df = pd.DataFrame(data=journal_list,
                         columns=["DOI", "Title", "Authors", "Corresponding Authors",
                                  "Institution",
                                  "Date", "Version", "Type", "Category", "Xml", "Published"])
journal_df
# Out:
#                 DOI                                              Title  \
# 0    10.1101/066688  Cross-scale dynamics and the evolutionary emer...
# 1    10.1101/079954  iCARE: An R Package to Build, Validate and App...
# 2    10.1101/093120  Darwinian selection of host and bacteria suppo...
# 3    10.1101/097816  Voltage-gated Proton Channel Hv1 Supports Insu...
# 4    10.1101/130989  On The Peopling Of The Americas: Molecular Evi...
# ..              ...                                                ...
# 625  10.1101/402404  Pat1 promotes processing body assembly by enha...
# 626  10.1101/402420  Assessment of population differentiation and l...
# 627  10.1101/402909  Identification of Small Molecule Modulators of...
# 628  10.1101/402362  Anti-angiogenic effects of VEGF stimulation on...
# 629  10.1101/401885  A single cell transcriptomic analysis of human...
#
#                                                Authors  \
# 0    Schreiber, S. J.; Ke, R.; Loverdo, C.; Park, M...
# 1    Pal Choudhury, P.; Maas, P.; Wilcox, A.; Wheel...
# 2    Osmanovic, D.; Kessler, D. A.; Rabin, Y.; Soen...
# 3    Pang, H.; Wang, X.; Xi, W.; Zhao, Q.; Zhang, S...
# 4                                  Yuan, D.; Huang, S.
# ..                                                 ...
# 625  Sachdev, R.; Hondele, M.; Linsenmeier, M.; Val...
# 626                   Lin, Y.-P.; Liu, C.-Y.; Chen, K.
# 627  Christen, M.; Kamischke, C.; Kulasekara, H. D....
# 628  Stratman, A. N.; Farrelly, O. M.; Mikelis, C. ...
# 629  Polioudakis, D.; de la Torre-Ubieta, L.; Lange...
#
#       Corresponding Authors  \
# 0    Sebastian J. Schreiber
# 1      Nilanjan  Chatterjee
# 2                Yoav  Soen
# 3               Shu Jie  Li
# 4                Shi  Huang
# ..                      ...
# 625           Karsten  Weis
# 626             Kaiyi  Chen
# 627      Matthias  Christen
# 628       Brant M Weinstein
# 629      Daniel H Geschwind
#
#                                            Institution        Date Version  \
# 0                      University of California, Davis  2018-08-21       2
# 1                             Johns Hopkins University  2018-08-23       2
# 2                        Weizmann Institute of Science  2018-08-21       5
# 3                                    Nankai University  2018-08-24       3
# 4                             Central South University  2018-08-23       3
# ..                                                 ...         ...     ...
# 625                                         ETH Zurich  2018-08-28       1
# 626                         National Taiwan University  2018-08-28       1
# 627  Eidgenoessische Technische Hochschule (ETH) Zu...  2018-08-28       1
# 628                                          NIH/NICHD  2018-08-28       1
# 629                                               UCLA  2018-08-28       1
#
#             Type              Category  \
# 0    new results          epidemiology
# 1    new results        bioinformatics
# 2    new results  evolutionary biology
# 3    new results          cell biology
# 4    new results  evolutionary biology
# ..           ...                   ...
# 625  new results          biochemistry
# 626  new results              genetics
# 627  new results          biochemistry
# 628  new results          cell biology
# 629  new results          neuroscience
#
#                                                    Xml  \
# 0    https://www.biorxiv.org/content/early/2018/08/...
# 1    https://www.biorxiv.org/content/early/2018/08/...
# 2    https://www.biorxiv.org/content/early/2018/08/...
# 3    https://www.biorxiv.org/content/early/2018/08/...
# 4    https://www.biorxiv.org/content/early/2018/08/...
# ..                                                 ...
# 625  https://www.biorxiv.org/content/early/2018/08/...
# 626  https://www.biorxiv.org/content/early/2018/08/...
# 627  https://www.biorxiv.org/content/early/2018/08/...
# 628  https://www.biorxiv.org/content/early/2018/08/...
# 629  https://www.biorxiv.org/content/early/2018/08/...
#
#                         Published
# 0              10.1093/ve/veaa105
# 1    10.1371/journal.pone.0228198
# 2       10.1186/s13062-018-0224-7
# 3                              NA
# 4                              NA
# ..                            ...
# 625           10.7554/elife.41415
# 626                            NA
# 627        10.1002/cbic.201800593
# 628    10.1038/s41467-020-14956-z
# 629                            NA
#
# [630 rows x 11 columns]

# %%
assert total == len(journal_df), 
"Total number of papers submitted and the length of the dataframe does not match."

# %% [markdown]
# The above code runs through all papers that are submitted within selected time frame. Error discussed during the previous meeting has been fixed.

# %% [markdown]
# ----

# %% [markdown]
# ### Junk Code
# Please disregard the codes below.

# %%
journal_list = []

# `license`,`abstract`, and `server` are excluded from the metrics. 
for journal in json_info["collection"]:
    journal_list.append([journal["doi"], journal["title"], journal["authors"],
                         journal["author_corresponding"], 
                         journal["author_corresponding_institution"],
                         journal["date"], journal["version"], journal["type"],
                         journal["category"], journal["jatsxml"], journal["published"]])

# %%
journal_df = pd.DataFrame(data=journal_list,
                         columns=["DOI", "Title", "Authors", "Corresponding Authors",
                                  "Institution",
                                  "Date", "Version", "Type", "Category", "Xml", "Published"])
journal_df.head()
# Out:
#               DOI                                              Title  \
# 0  10.1101/402644  Resting shear elastic modulus as a marker of p...
# 1  10.1101/402701  Enterotype-like microbiome stratification as e...
# 2  10.1101/402560  An open-source software analysis package for M...
# 3  10.1101/402586  Over-expression of the photoperiod response re...
# 4  10.1101/402743  A natural history model for planning prostate ...
#
#                                              Authors Corresponding Authors  \
# 0  SIRACUSA, J.; CHARLOT, K.; MALGOYRE, A.; CONOR...      Julien  SIRACUSA
# 1                                      Martin, M. A.  Miguel Angel  Martin
# 2     Harink, B.; Nguyen, H.; Thorn, K.; Fordyce, P.        Polly  Fordyce
# 3  Stephenson, E.; Estrada, S.; Meng, X.; Ourada,...    Olga  Danilevskaya
# 4  Karlsson, A.; Jauhiainen, A.; Gulati, R.; Eklu...     Andreas  Karlsson
#
#                                          Institution        Date Version  \
# 0                                               IRBA  2018-08-28       1
# 1  Universidad Politecnica de Madrid Centro de Es...  2018-08-28       1
# 2                                Stanford University  2018-08-28       1
# 3                                     DuPont Pioneer  2018-08-28       1
# 4                               Karolinska Institute  2018-08-28       1
#
#           Type               Category  \
# 0  new results             physiology
# 1  new results        systems biology
# 2  new results         bioengineering
# 3  new results  developmental biology
# 4  new results           epidemiology
#
#                                                  Xml  \
# 0  https://www.biorxiv.org/content/early/2018/08/...
# 1  https://www.biorxiv.org/content/early/2018/08/...
# 2  https://www.biorxiv.org/content/early/2018/08/...
# 3  https://www.biorxiv.org/content/early/2018/08/...
# 4  https://www.biorxiv.org/content/early/2018/08/...
#
#                       Published
# 0                            NA
# 1     10.1142/S0218348X21502108
# 2  10.1371/journal.pone.0203725
# 3  10.1371/journal.pone.0203728
# 4  10.1371/journal.pone.0211918
